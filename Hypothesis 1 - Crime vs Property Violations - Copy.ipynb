# %%
import pandas as pd
import json

# %%
df_crime = pd.read_csv('data/raw/CrimeData2020-withlocality.csv')
df_311 = pd.read_csv('data/raw/311_Block_Group_Processed.csv')

# %%
print(len(df_crime), df_crime.columns)
df_crime = df_crime[df_crime['Description'].str.len() > 0].loc[: , ['Description','Formatted Address', 'From_Date', 'From_Time', 'To_Date',
                                               'To_Time',
                                               'Offense', 'Race', 'Rep_Dist',
                                               'Sex', 'blockgroup_id', 'lat', 'lng', 'nbh_name',
                                               'nbhid', 'police_division', 'police_division_id']].reset_index(drop=True)
df_crime.head()
# Out:
# 89269 Index(['Address', 'Age', 'Area', 'Beat', 'City', 'DVFlag', 'Description',
#        'Firearm Used Flag', 'Formatted Address', 'From_Date', 'From_Time',
#        'IBRS', 'Involvement', 'Location', 'Offense', 'Race', 'Rep_Dist',
#        'Report_No', 'Reported_Date', 'Reported_Time', 'Sex', 'To_Date',
#        'To_Time', 'Zip Code', 'blockgroup_id', 'lat', 'lng', 'nbh_name',
#        'nbhid', 'police_division', 'police_division_id'],
#       dtype='object')
#           Description                               Formatted Address  \
# 0             Robbery      3800 Agnes Ave, Kansas City, MO 64128, USA
# 1         Shoplifting      200 Nichols Rd, Kansas City, MO 64112, USA
# 2  Aggravated Assault  800 NE Windrose Ct, Kansas City, MO 64155, USA
# 3   All Other Larceny      1800 E 79th St, Kansas City, MO 64131, USA
# 4             Robbery      1600 E 40th St, Kansas City, MO 64110, USA
#
#     From_Date From_Time     To_Date To_Time  \
# 0  01/01/2020     18:39         NaN     NaN
# 1  12/30/2019     17:50  12/30/2019   18:00
# 2  01/03/2020     08:30         NaN     NaN
# 3  01/05/2020     18:40         NaN     NaN
# 4  01/06/2020     00:43         NaN     NaN
#
#                                   Offense Race Rep_Dist  Sex  blockgroup_id  \
# 0                   Robbery (Residential)    B   PJ3113    M   2.909501e+11
# 1                     Stealing – Shoplift  NaN      NaN  NaN   2.909501e+11
# 2  Domestic Violence Assault (Aggravated)    W      NaN    M   2.904702e+11
# 3                        Stealing – Other    W      NaN    M   2.909501e+11
# 4                  Robbery (Armed Street)    B      NaN    F   2.909502e+11
#
#          lat        lng            nbh_name  nbhid police_division  \
# 0  39.056963 -94.549126  Oak Park Northwest     58            East
# 1  39.041515 -94.589762  Country Club Plaza     85         Central
# 2  39.259149 -94.570858            Gashland    236     Shoal Creek
# 3  38.984189 -94.567016        East Meyer 6    128           Metro
# 4  39.054227 -94.565100   Ivanhoe Southwest     53         Central
#
#    police_division_id
# 0                 3.0
# 1                 1.0
# 2                 6.0
# 3                 2.0
# 4                 1.0

# %%
df_crime
# Out:
#                           Description  \
# 0                             Robbery
# 1                         Shoplifting
# 2                  Aggravated Assault
# 3                   All Other Larceny
# 4                             Robbery
# ...                               ...
# 80743             Motor Vehicle Theft
# 80744  Burglary/Breaking and Entering
# 80745        Theft From Motor Vehicle
# 80746                    Embezzlement
# 80747  Burglary/Breaking and Entering
#
#                                        Formatted Address   From_Date  \
# 0             3800 Agnes Ave, Kansas City, MO 64128, USA  01/01/2020
# 1             200 Nichols Rd, Kansas City, MO 64112, USA  12/30/2019
# 2         800 NE Windrose Ct, Kansas City, MO 64155, USA  01/03/2020
# 3             1800 E 79th St, Kansas City, MO 64131, USA  01/05/2020
# 4             1600 E 40th St, Kansas City, MO 64110, USA  01/06/2020
# ...                                                  ...         ...
# 80743  11800 Blue Ridge Blvd, Kansas City, MO 64134, USA  11/30/2020
# 80744       3300 Harrison St, Kansas City, MO 64109, USA  12/05/2020
# 80745          500 Locust Ln, Kansas City, MO 64106, USA  12/16/2020
# 80746        13900 Blue Pkwy, Kansas City, MO 64139, USA  08/15/2020
# 80747       1600 Topping Ave, Kansas City, MO 64127, USA  12/08/2020
#
#       From_Time     To_Date To_Time                                 Offense  \
# 0         18:39         NaN     NaN                   Robbery (Residential)
# 1         17:50  12/30/2019   18:00                     Stealing – Shoplift
# 2         08:30         NaN     NaN  Domestic Violence Assault (Aggravated)
# 3         18:40         NaN     NaN                        Stealing – Other
# 4         00:43         NaN     NaN                  Robbery (Armed Street)
# ...         ...         ...     ...                                     ...
# 80743     12:00  12/03/2020   08:00                             Stolen Auto
# 80744     05:29  12/05/2020   05:29                  Burglary (Residential)
# 80745     05:30         NaN     NaN    Stealing from Auto (Theft from Auto)
# 80746     20:32  09/07/2020   20:33                            Embezzlement
# 80747     18:10         NaN     NaN                  Burglary (Residential)
#
#       Race Rep_Dist  Sex  blockgroup_id        lat        lng  \
# 0        B   PJ3113    M   2.909501e+11  39.056963 -94.549126
# 1      NaN      NaN  NaN   2.909501e+11  39.041515 -94.589762
# 2        W      NaN    M   2.904702e+11  39.259149 -94.570858
# 3        W      NaN    M   2.909501e+11  38.984189 -94.567016
# 4        B      NaN    F   2.909502e+11  39.054227 -94.565100
# ...    ...      ...  ...            ...        ...        ...
# 80743  NaN      NaN  NaN   2.909501e+11  39.057473 -94.557980
# 80744    B   PJ2706    M   2.909502e+11  39.066905 -94.572888
# 80745    W      NaN    M   2.909501e+11  39.057473 -94.557980
# 80746  NaN      NaN  NaN   2.909501e+11  38.961143 -94.422389
# 80747    W   PJ1548    M   2.909501e+11  39.057473 -94.557980
#
#                  nbh_name  nbhid police_division  police_division_id
# 0      Oak Park Northwest     58            East                 3.0
# 1      Country Club Plaza     85         Central                 1.0
# 2                Gashland    236     Shoal Creek                 6.0
# 3            East Meyer 6    128           Metro                 2.0
# 4       Ivanhoe Southwest     53         Central                 1.0
# ...                   ...    ...             ...                 ...
# 80743   Ivanhoe Northeast     55         Central                 1.0
# 80744     North Hyde Park     76         Central                 1.0
# 80745   Ivanhoe Northeast     55         Central                 1.0
# 80746         Little Blue    178           South                 5.0
# 80747   Ivanhoe Northeast     55         Central                 1.0
#
# [80748 rows x 17 columns]

# %% [markdown]
# <h1> Simplifying Property Violations

# %%
# df_PropVlt = df_311[(df_311['CREATION YEAR'] == 2020) & 
#        ((df_311['REQUEST TYPE'] == 'Property Violations') | (df_311['CATEGORY'] == 'Property Violations'))].reset_index(drop = True)
df_PropVlt = df_311[
       (df_311['REQUEST TYPE'] == 'Property Violations') | (df_311['CATEGORY'] == 'Property Violations')].reset_index(drop = True)


df_PropVlt
# Out:
#            CASE ID SOURCE DEPARTMENT                      WORK GROUP  \
# 0       2020149407  PHONE        NHS  NHS-Neighborhood Preservation-
# 1       2020149677    WEB        NHS  NHS-Neighborhood Preservation-
# 2       2020131202    WEB        NHS  NHS-Neighborhood Preservation-
# 3       2020087852  PHONE        NHS  NHS-Neighborhood Preservation-
# 4       2020131287    WEB        NHS  NHS-Neighborhood Preservation-
# ...            ...    ...        ...                             ...
# 246431  2020109674  PHONE        NHS  NHS-Neighborhood Preservation-
# 246432  2020111414  PHONE        NHS  NHS-Neighborhood Preservation-
# 246433  2020146098  PHONE        NHS  NHS-Neighborhood Preservation-
# 246434  2020152424    WEB        NHS  NHS-Neighborhood Preservation-
# 246435  2020154466  PHONE        NHS  NHS-Neighborhood Preservation-
#
#                REQUEST TYPE                             CATEGORY  \
# 0       Property Violations  Property / Buildings / Construction
# 1       Property Violations                    Trash / Recycling
# 2       Property Violations  Property / Buildings / Construction
# 3       Property Violations  Property / Buildings / Construction
# 4       Property Violations  Property / Buildings / Construction
# ...                     ...                                  ...
# 246431  Property Violations  Property / Buildings / Construction
# 246432  Property Violations  Property / Buildings / Construction
# 246433  Property Violations  Property / Buildings / Construction
# 246434  Property Violations  Property / Buildings / Construction
# 246435  Property Violations  Property / Buildings / Construction
#
#                         TYPE                DETAIL CREATION DATE  \
# 0       Property Maintenance  Other Property Issue    11/25/2020
# 1                   Nuisance          Open Storage    11/25/2020
# 2       Property Maintenance  Other Property Issue    10/02/2020
# 3       Property Maintenance        Main Structure    06/25/2020
# 4       Property Maintenance              Graffiti    10/04/2020
# ...                      ...                   ...           ...
# 246431  Property Maintenance        Main Structure    08/12/2020
# 246432  Property Maintenance        Main Structure    08/17/2020
# 246433  Property Maintenance        Main Structure    11/16/2020
# 246434  Property Maintenance              Graffiti    12/05/2020
# 246435  Property Maintenance        Main Structure    12/10/2020
#
#        CREATION TIME  ...                    NEIGHBORHOOD   COUNTY  \
# 0           09:19 AM  ...       East Community Team South  Jackson
# 1           06:39 PM  ...                 North Hyde Park  Jackson
# 2           05:23 PM  ...       East Community Team North  Jackson
# 3           11:15 AM  ...             Washington Wheatley  Jackson
# 4           02:46 PM  ...                          Lykins  Jackson
# ...              ...  ...                             ...      ...
# 246431      11:29 AM  ...  Self Help Neighborhood Council  Jackson
# 246432      09:53 AM  ...                   Key Coalition  Jackson
# 246433      02:51 PM  ...                East Blue Valley  Jackson
# 246434      10:35 AM  ...                Wendell Phillips  Jackson
# 246435      04:09 PM  ...                 KCI & 2nd Creek   Platte
#
#        COUNCIL DISTRICT POLICE DISTRICT PARCEL ID NO   LATITUDE  LONGITUDE  \
# 0                   3.0            East        19178  39.079895 -94.526959
# 1                   4.0         Central       128496  39.064579 -94.575951
# 2                   3.0            East       240392  39.094498 -94.532335
# 3                   3.0            East        17447  39.080129 -94.541614
# 4                   3.0            East         7850  39.104700 -94.523963
# ...                 ...             ...          ...        ...        ...
# 246431              5.0           Metro         2769  39.001799 -94.550551
# 246432              3.0         Central       126460  39.064743 -94.558602
# 246433              3.0            East         7206  39.091286 -94.505295
# 246434              3.0         Central        12974  39.089248 -94.557082
# 246435              2.0           North       250378  39.261089 -94.621594
#
#                                                  CASE URL  \
# 0       http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1       http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 2       http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 3       http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 4       http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# ...                                                   ...
# 246431  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 246432  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 246433  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 246434  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 246435  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
#
#        30-60-90 Days Open Window      block_id
# 0                            0.0  2.909500e+11
# 1                            NaN  2.909502e+11
# 2                            NaN  2.909500e+11
# 3                            NaN  2.909502e+11
# 4                            0.0  2.909500e+11
# ...                          ...           ...
# 246431                       NaN  2.909501e+11
# 246432                       NaN  2.909501e+11
# 246433                       0.0  2.909500e+11
# 246434                       NaN  2.909502e+11
# 246435                       0.0  2.916503e+11
#
# [246436 rows x 31 columns]

# %%
sorted(df_PropVlt['CREATION YEAR'].unique().tolist())
# Out:
# [2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021]

# %%
requestType_dict = {x:[] for x in df_PropVlt['REQUEST TYPE'].unique().tolist()}
for i, g in df_PropVlt.groupby(['REQUEST TYPE','CATEGORY']):
#     print(i)
    requestType_dict[i[0]].append(i[1])
#     display(g)
category_dict = {x:[] for x in df_PropVlt['CATEGORY'].unique().tolist()}
for i, g in df_PropVlt.groupby(['CATEGORY','TYPE']):
#     print(i)
    category_dict[i[0]].append(i[1])
#     display(g)
    
type_dict = {x:[] for x in df_PropVlt['TYPE'].unique().tolist()}
for i, g in df_PropVlt.groupby(['TYPE','DETAIL']):
#     print(i)
    type_dict[i[0]].append(i[1])
#     display(g)

# %%
print(requestType_dict)
# print(category_dict)
# print(type_dict)
# Out:
# {'Property Violations': ['Mowing / Weeds'], 'Mowing / Weeds-Public Property-City Vacant Lot': ['Mowing / Weeds'], 'Vacant Structure Open to Entry': ['Property Violations'], 'Animals / Pets-Rat Treatment-Vacant Home': ['Animals / Pets'], 'Animals / Pets-Rat Treatment-Vacant Property': ['Animals / Pets'], 'Nuisance Violations on Private Property Vacant Structure': ['Property & Nuisance Violations']}

# %%
len(requestType_dict)
# Out:
# 11

# %%
'''
Request Type -> Category -> Type -> Detail Hierarchy
'''
hierarchy_obj = []
for k,v in requestType_dict.items():
    # print(k,v)
    rqType_obj = {
    "name": k,
    "parent": "null",
    "children": []
    }
    '''
    Category -> Type 
    '''
    for cat in v:
        cat_obj = {
            "name": cat,
            "parent": k,
            'children': []
          }
        '''
        Type -> Detail 
        '''
        for typ in category_dict[cat]:
            type_obj = {
            "name": typ,
            "parent": cat,
            'children': []
            }
            for detail in type_dict[typ]:
                det_obj = {
                    "name": detail,
                    "parent": typ,
                }
                type_obj['children'].append(det_obj)
            cat_obj['children'].append(type_obj)

        rqType_obj['children'].append(cat_obj)


    hierarchy_obj.append(rqType_obj)
    # break

with open('property_violations_hierarchy.json', 'w') as f:
    json_obj = json.dumps(hierarchy_obj, indent = 4)
    f.write(json_obj)
print(json_obj)
# Out:
#                  {
#                                 "name": "All",
#                                 "parent": "Board Up"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Private Property",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "Accelerated Abatement",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "All",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Dead",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "No Known Property Owner",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Priority Review",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Snow on Sidewalk",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Tree Debris",
#                                 "parent": "Private Property"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Volunteer Inspector Program",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Volunteer Inspector Program"
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "name": "Dangerous Building and Emergency Board Up",
#         "parent": "null",
#         "children": [
#             {
#                 "name": "Property Violations",
#                 "parent": "Dangerous Building and Emergency Board Up",
#                 "children": [
#                     {
#                         "name": "Board Up",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Board Up"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Private Property",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "Accelerated Abatement",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "All",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Dead",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "No Known Property Owner",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Priority Review",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Snow on Sidewalk",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Tree Debris",
#                                 "parent": "Private Property"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Volunteer Inspector Program",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Volunteer Inspector Program"
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "name": "Dangerous Building Emergency",
#         "parent": "null",
#         "children": [
#             {
#                 "name": "Property Violations",
#                 "parent": "Dangerous Building Emergency",
#                 "children": [
#                     {
#                         "name": "Board Up",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Board Up"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Private Property",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "Accelerated Abatement",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "All",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Dead",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "No Known Property Owner",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Priority Review",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Snow on Sidewalk",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Tree Debris",
#                                 "parent": "Private Property"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Volunteer Inspector Program",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Volunteer Inspector Program"
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "name": "No Known Property Owner",
#         "parent": "null",
#         "children": [
#             {
#                 "name": "Property Violations",
#                 "parent": "No Known Property Owner",
#                 "children": [
#                     {
#                         "name": "Board Up",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Board Up"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Private Property",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "Accelerated Abatement",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "All",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Dead",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "No Known Property Owner",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Priority Review",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Snow on Sidewalk",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Tree Debris",
#                                 "parent": "Private Property"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Volunteer Inspector Program",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Volunteer Inspector Program"
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "name": "Referral for Sewage on Private Property",
#         "parent": "null",
#         "children": [
#             {
#                 "name": "Property Violations",
#                 "parent": "Referral for Sewage on Private Property",
#                 "children": [
#                     {
#                         "name": "Board Up",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Board Up"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Private Property",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "Accelerated Abatement",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "All",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Dead",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "No Known Property Owner",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Priority Review",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Snow on Sidewalk",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Tree Debris",
#                                 "parent": "Private Property"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Volunteer Inspector Program",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Volunteer Inspector Program"
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "name": "Accelerated Abatement Program",
#         "parent": "null",
#         "children": [
#             {
#                 "name": "Property Violations",
#                 "parent": "Accelerated Abatement Program",
#                 "children": [
#                     {
#                         "name": "Board Up",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Board Up"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Private Property",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "Accelerated Abatement",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "All",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Dead",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "No Known Property Owner",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Priority Review",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Snow on Sidewalk",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Tree Debris",
#                                 "parent": "Private Property"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Volunteer Inspector Program",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Volunteer Inspector Program"
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "name": "Volunteer Inspection Program",
#         "parent": "null",
#         "children": [
#             {
#                 "name": "Property Violations",
#                 "parent": "Volunteer Inspection Program",
#                 "children": [
#                     {
#                         "name": "Board Up",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Board Up"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Private Property",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "Accelerated Abatement",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "All",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Dead",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "No Known Property Owner",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Priority Review",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Snow on Sidewalk",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Tree Debris",
#                                 "parent": "Private Property"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Volunteer Inspector Program",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Volunteer Inspector Program"
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "name": "Snow or Ice on Sidewalk",
#         "parent": "null",
#         "children": [
#             {
#                 "name": "Property Violations",
#                 "parent": "Snow or Ice on Sidewalk",
#                 "children": [
#                     {
#                         "name": "Board Up",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Board Up"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Private Property",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "Accelerated Abatement",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "All",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Dead",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "No Known Property Owner",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Priority Review",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Snow on Sidewalk",
#                                 "parent": "Private Property"
#                             },
#                             {
#                                 "name": "Tree Debris",
#                                 "parent": "Private Property"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Volunteer Inspector Program",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Volunteer Inspector Program"
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     }
# ]

# %%
'''
Category -> Type -> Detail Hierarchy
'''
hierarchy_obj = [{
    "name": '311 Categories',
    "parent": 'null',
    'children': []
    }
]

'''
Category -> Type 
'''
for k,v in category_dict.items():
    cat_obj = {
        "name": k,
        "parent": '311 Categories',
        'children': []
        }
    '''
    Type -> Detail 
    '''
    for typ in v:
        type_obj = {
        "name": typ,
        "parent": cat,
        'children': []
        }
        for detail in type_dict[typ]:
            det_obj = {
                "name": detail,
                "parent": typ,
            }
            type_obj['children'].append(det_obj)
        cat_obj['children'].append(type_obj)

    rqType_obj['children'].append(cat_obj)


    hierarchy_obj[0]['children'].append(cat_obj)
#    break

with open('property_violations_hierarchy.json', 'w') as f:
    json_obj = json.dumps(hierarchy_obj, indent = 4)
    f.write(json_obj)
print(json_obj)
# Out:
# [
#     {
#         "name": "311 Categories",
#         "parent": "null",
#         "children": [
#             {
#                 "name": "Property Violations",
#                 "parent": "311 Categories",
#                 "children": [
#                     {
#                         "name": "Board Up",
#                         "parent": "Mowing / Weeds",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Board Up"
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "Mowing / Weeds",
#                 "parent": "311 Categories",
#                 "children": [
#                     {
#                         "name": "Private / Commercial",
#                         "parent": "Mowing / Weeds",
#                         "children": [
#                             {
#                                 "name": "Lot - Vacant",
#                                 "parent": "Private / Commercial"
#                             }
#                         ]
#                     },
#                     {
#                         "name": "Public Property",
#                         "parent": "Mowing / Weeds",
#                         "children": [
#                             {
#                                 "name": "City Vacant Lot",
#                                 "parent": "Public Property"
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "Property & Nuisance Violations",
#                 "parent": "311 Categories",
#                 "children": [
#                     {
#                         "name": "Private Property",
#                         "parent": "Mowing / Weeds",
#                         "children": [
#                             {
#                                 "name": "All",
#                                 "parent": "Private Property"
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "Animals / Pets",
#                 "parent": "311 Categories",
#                 "children": [
#                     {
#                         "name": "Rat Treatment",
#                         "parent": "Mowing / Weeds",
#                         "children": [
#                             {
#                                 "name": "Vacant Lot",
#                                 "parent": "Rat Treatment"
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     }
# ]

# %%
category_dict.keys()
# Out:
# dict_keys(['Property / Buildings / Construction', 'Trash / Recycling', 'Trees', 'Vehicles / Parking', 'Mowing / Weeds', 'Property Violations', 'Data Not Available', 'Animals / Pets', 'Sidewalks / Curbs / Ditch', 'Storm Water / Sewer', 'Neighborhood Preservation'])

# %% [markdown]
# <h1> 311 Vacant Calls

# %%
df_Vacant311 = df_311.copy().loc[:, ['REQUEST TYPE', 'CATEGORY', 'TYPE', 'DETAIL']]
df_Vacant311 =df_Vacant311[df_Vacant311.apply(lambda col: col.str.contains('Vacant', na=False), axis=1).any(1)]

df_Vacant311
# Out:
#                 REQUEST TYPE        CATEGORY                  TYPE  \
# 145      Property Violations  Mowing / Weeds  Private / Commercial
# 159      Property Violations  Mowing / Weeds  Private / Commercial
# 428      Property Violations  Mowing / Weeds  Private / Commercial
# 555      Property Violations  Mowing / Weeds  Private / Commercial
# 556      Property Violations  Mowing / Weeds  Private / Commercial
# ...                      ...             ...                   ...
# 1543219  Property Violations  Mowing / Weeds  Private / Commercial
# 1544128  Property Violations  Mowing / Weeds  Private / Commercial
# 1544647  Property Violations  Mowing / Weeds  Private / Commercial
# 1544741  Property Violations  Mowing / Weeds  Private / Commercial
# 1544969  Property Violations  Mowing / Weeds  Private / Commercial
#
#                DETAIL
# 145      Lot - Vacant
# 159      Lot - Vacant
# 428      Lot - Vacant
# 555      Lot - Vacant
# 556      Lot - Vacant
# ...               ...
# 1543219  Lot - Vacant
# 1544128  Lot - Vacant
# 1544647  Lot - Vacant
# 1544741  Lot - Vacant
# 1544969  Lot - Vacant
#
# [30467 rows x 4 columns]

# %%
requestType_dict = {x:[] for x in df_PropVlt['REQUEST TYPE'].unique().tolist()}
for i, g in df_PropVlt.groupby(['REQUEST TYPE','CATEGORY']):
#     print(i)
    requestType_dict[i[0]].append(i[1])
#     display(g)
category_dict = {x:[] for x in df_PropVlt['CATEGORY'].unique().tolist()}
for i, g in df_PropVlt.groupby(['CATEGORY','TYPE']):
#     print(i)
    category_dict[i[0]].append(i[1])
#     display(g)
    
type_dict = {x:[] for x in df_PropVlt['TYPE'].unique().tolist()}
for i, g in df_PropVlt.groupby(['TYPE','DETAIL']):
#     print(i)
    type_dict[i[0]].append(i[1])
#     display(g)

# %%
'''
Request Type -> Category -> Type -> Detail Hierarchy
'''
hierarchy_obj = [{
    "name": '311 Vacant Calls',
    "parent": 'null',
    'children': []
    }
]

for k,v in requestType_dict.items():
    # print(k,v)
    rqType_obj = {
    "name": k,
    "parent": "null",
    "children": []
    }
    '''
    Category -> Type 
    '''
    for cat in v:
        cat_obj = {
            "name": cat,
            "parent": k,
            'children': []
          }
        '''
        Type -> Detail 
        '''
        for typ in category_dict[cat]:
            type_obj = {
            "name": typ,
            "parent": cat,
            'children': []
            }
            for detail in type_dict[typ]:
                det_obj = {
                    "name": detail,
                    "parent": typ,
                }
                type_obj['children'].append(det_obj)
            cat_obj['children'].append(type_obj)

        rqType_obj['children'].append(cat_obj)


    hierarchy_obj[0]['children'].append(rqType_obj)
    # break

with open('311_vacant_hierarchy.json', 'w') as f:
    json_obj = json.dumps(hierarchy_obj, indent = 4)
    f.write(json_obj)
print(json_obj)
# Out:
# [
#     {
#         "name": "311 Vacant Calls",
#         "parent": "null",
#         "children": [
#             {
#                 "name": "Property Violations",
#                 "parent": "null",
#                 "children": [
#                     {
#                         "name": "Mowing / Weeds",
#                         "parent": "Property Violations",
#                         "children": [
#                             {
#                                 "name": "Private / Commercial",
#                                 "parent": "Mowing / Weeds",
#                                 "children": [
#                                     {
#                                         "name": "Lot - Vacant",
#                                         "parent": "Private / Commercial"
#                                     }
#                                 ]
#                             },
#                             {
#                                 "name": "Public Property",
#                                 "parent": "Mowing / Weeds",
#                                 "children": [
#                                     {
#                                         "name": "City Vacant Lot",
#                                         "parent": "Public Property"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "Mowing / Weeds-Public Property-City Vacant Lot",
#                 "parent": "null",
#                 "children": [
#                     {
#                         "name": "Mowing / Weeds",
#                         "parent": "Mowing / Weeds-Public Property-City Vacant Lot",
#                         "children": [
#                             {
#                                 "name": "Private / Commercial",
#                                 "parent": "Mowing / Weeds",
#                                 "children": [
#                                     {
#                                         "name": "Lot - Vacant",
#                                         "parent": "Private / Commercial"
#                                     }
#                                 ]
#                             },
#                             {
#                                 "name": "Public Property",
#                                 "parent": "Mowing / Weeds",
#                                 "children": [
#                                     {
#                                         "name": "City Vacant Lot",
#                                         "parent": "Public Property"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "Vacant Structure Open to Entry",
#                 "parent": "null",
#                 "children": [
#                     {
#                         "name": "Property Violations",
#                         "parent": "Vacant Structure Open to Entry",
#                         "children": [
#                             {
#                                 "name": "Board Up",
#                                 "parent": "Property Violations",
#                                 "children": [
#                                     {
#                                         "name": "All",
#                                         "parent": "Board Up"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "Animals / Pets-Rat Treatment-Vacant Home",
#                 "parent": "null",
#                 "children": [
#                     {
#                         "name": "Animals / Pets",
#                         "parent": "Animals / Pets-Rat Treatment-Vacant Home",
#                         "children": [
#                             {
#                                 "name": "Rat Treatment",
#                                 "parent": "Animals / Pets",
#                                 "children": [
#                                     {
#                                         "name": "Vacant Home",
#                                         "parent": "Rat Treatment"
#                                     },
#                                     {
#                                         "name": "Vacant Lot",
#                                         "parent": "Rat Treatment"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "Animals / Pets-Rat Treatment-Vacant Property",
#                 "parent": "null",
#                 "children": [
#                     {
#                         "name": "Animals / Pets",
#                         "parent": "Animals / Pets-Rat Treatment-Vacant Property",
#                         "children": [
#                             {
#                                 "name": "Rat Treatment",
#                                 "parent": "Animals / Pets",
#                                 "children": [
#                                     {
#                                         "name": "Vacant Home",
#                                         "parent": "Rat Treatment"
#                                     },
#                                     {
#                                         "name": "Vacant Lot",
#                                         "parent": "Rat Treatment"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "name": "Nuisance Violations on Private Property Vacant Structure",
#                 "parent": "null",
#                 "children": [
#                     {
#                         "name": "Property & Nuisance Violations",
#                         "parent": "Nuisance Violations on Private Property Vacant Structure",
#                         "children": [
#                             {
#                                 "name": "Private Property",
#                                 "parent": "Property & Nuisance Violations",
#                                 "children": [
#                                     {
#                                         "name": "All",
#                                         "parent": "Private Property"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     }
# ]
