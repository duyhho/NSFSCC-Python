# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Mounted at /content/gdrive
# ...
# time: 2.02 ms (started: 2021-03-27 09:46:50 +00:00)

# %%
# !mkdir data/
# !cp "/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/230-BG.csv" data/
# !cp "/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census_Variables.csv" data/
# !cp -r "/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census" data/


# !unzip '246-KCMO-ALL-Neighborhoods.zip' -d ./data/

# %%
# !pip install CensusData

# %%
import pandas as pd
import censusdata
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.precision', 2)
pd.options.display.float_format = '{:,}'.format

# %%
import pandas as pd
# df_2019_fixed = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019/Census_validBG_fixed_withNN.csv')
BG_df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/311_Block_Group_Processed.csv')
display(BG_df.head())
TARGET_BGS = BG_df['block_id'].dropna().astype(int).astype(str).unique().tolist()
TARGET_BGS

# %%
census_result = censusdata.search('acs5', 2019, 'concept', 'Geography Specification')

census_result

# %%
censusdata.printtable(censusdata.censustable('acs5', 2017, 'B11001'))

# %%
all_counties = censusdata.geographies(censusdata.censusgeo([('state', '29'), ('county', '*')]), 'acs5', 2019)

all_counties_ID = []
for cty, geo in all_counties.items():
  all_counties_ID.append(geo.params()[1][1])
  # break
all_counties_ID = sorted(all_counties_ID)
all_counties_ID

# %%
# censusdata.geographies(censusdata.censusgeo([('state', '29'), ('county', '095'),  ('block group', '*')]), 'acs5', 2019)

# %%
# Full API variable list available here https://api.census.gov/data/2016/acs/acs5/variables/
categories = {
      # Socioeconomic
     'B01001_001E': 'Total population',
     'B19013_001E': 'Median income',
     'B25077_001E': 'Median home value',
     'B15011_001E': 'Earned a bachelor\'s degree or higher',

     'B23025_003E': 'In civilian labor force',
     'B23025_004E': 'Employed',
     'B23025_005E': 'Unemployed',



     'B03002_003E': 'White alone',
     'B03002_004E': 'Black or African American alone',
     'B03002_006E': 'Asian alone',
     'B03002_012E': 'Hispanic or Latino',
     
     'B25002_003E': 'Total Vacant',
     'B25003_003E': 'Total Renter Occupied',
     'B11001_001E': 'Number of Households',

     'B17010_001E': 'Families considered in poverty calculation',
     'B17021_001E': 'Individuals considered in poverty calculation',
     'B17017_001E': 'Households considered in poverty calculation',

     'B17010_002E': 'Families with income below poverty',
     'B17021_002E': 'Individuals with income below poverty',
     'B17017_002E': 'Households with income below poverty',

      'B15003_001E': 'Total population 25 or older',
      'B15003_002E': 'No schooling completed',
      'B15003_016E': 'High school diploma',
      'B15003_022E': 'Bachelor\'s degree',
      'B15003_023E': 'Master\'s degree',
      'B15003_025E': 'Doctorate degree',
} #2013-above
TARGET_VARIABLES = list(categories.keys())[:]
[categories[x] for x in TARGET_VARIABLES]

# interest_df = pd.read_csv('data/Census_Variables.csv')
# interest_df = interest_df[interest_df['Name'].str.contains('DP') == False]
# interest_df.index = interest_df['Name']
# display(interest_df)

# TARGET_VARIABLES = interest_df['Name'].tolist()
# TARGET_LABELS = interest_df['Label'].tolist()
# TARGET_VARIABLES, TARGET_LABELS

# %%
# !mkdir data/
# !mkdir data/Census
# !mkdir data/Census/465
from tqdm.notebook import tqdm
TARGET_YEARS = range(2019, 2012, -1)
for year in TARGET_YEARS:
  TARGET_YEAR = year
  print(TARGET_YEAR)
  master_df = pd.DataFrame()
  for id in tqdm(all_counties_ID):
    download_df = censusdata.download('acs5', TARGET_YEAR, censusdata.censusgeo([('state', '29'), ('county', id), ('block group', '*')]),TARGET_VARIABLES)
    master_df = pd.concat([master_df, download_df], axis=0)
    # break
  # print(len(master_df))


  '''
      'B01001_001E', # Total population
      'B19013_001E', # Median income
      'B25077_001E', # Median home value
      'B15011_001E', # Total population age 25+ years with a bachelor's degree or higher
      'B03002_003E', # Not Hispanic or Latino!!White alone
      'B03002_004E', # Not Hispanic or Latino!!Black or African American alone
      'B02001_004E', # American Indian and Alaska Native Alone
      'B03002_006E', # Not Hispanic or Latino!!Asian alone
      'B03002_007E', # Not Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone
      'B03002_008E', # Not Hispanic or Latino!!Some other race alone
      'B03002_009E', # Not Hispanic or Latino!!Two or more races
      'B03002_012E', # Hispanic or Latino

  '''     
  indices = master_df.index.tolist()
  GEO_IDs = []
  # print(indices)
  for idx in indices:
    # print(idx)
    state, county, tract, bg = idx.params()
    if bg[1] is None:
      bg = idx.name[12]
      geo_id = state[1] + county[1] + tract[1] + bg
    else:
      geo_id = state[1] + county[1] + tract[1] + bg[1]
    GEO_IDs.append(geo_id)
  master_df.index = GEO_IDs
  master_df.columns = [categories[x] for x in TARGET_VARIABLES]
  master_df['BLOCKGROUP_ID'] = master_df.index
  cols = master_df.columns.tolist()
  cols.insert(0, cols.pop(cols.index('BLOCKGROUP_ID')))
  master_df = master_df.reindex(columns= cols)
  # master_df = master_df[master_df['BLOCKGROUP_ID'].isin(TARGET_BGS)]

  incomplete_df = master_df.loc[master_df[cols[1:]].values < 0].copy().drop_duplicates()
  incomplete_index = incomplete_df.index
  complete_df = master_df.loc[master_df.index.isin(incomplete_index) == False].copy().reset_index(drop=True).drop_duplicates()
  incomplete_df = incomplete_df.reset_index(drop=True).drop_duplicates()

  # display(complete_df)
  # display(incomplete_df)
  # !rm -rf data/Census/465/$TARGET_YEAR
  # !mkdir data/Census/465/$TARGET_YEAR
  master_df.to_csv('data/Census/465/{}/BG_465_Census.csv'.format(TARGET_YEAR), index=False)
  incomplete_df.to_csv('data/Census/465/{}/Census-corruptBG.csv'.format(TARGET_YEAR), index=False)
  complete_df.to_csv('data/Census/465/{}/Census-validBG.csv'.format(TARGET_YEAR), index=False)

  break

# %%
incomplete_df[incomplete_df['BLOCKGROUP_ID'].isin(TARGET_BGS)].reset_index(drop=True)

# %%
# !cp -r data/Census/465 "/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/"

# %%
# https://api.census.gov/data/2019/acs/acs5/profile?get=DP02_0001E&for=state:01

# %%
master_df.to_csv('BG_info.csv', index=False)

# %%
valid_df = download_df[download_df['B07010_001E'].isnull() == False]
valid_df

# %% [markdown]
# # Handling Missing Data

# %%
import pandas as pd
df_2019 = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019/Census-corruptBG.csv')
df_2019.index = df_2019['BLOCKGROUP_ID']
df_2019

# %%
df_2019[df_2019['BLOCKGROUP_ID'].isin(TARGET_BGS)].reset_index(drop=True)

# %%
len(df_2019[((df_2019 <= 0).sum(1) >= 12)])

# %%
df_2019_alt = pd.DataFrame(columns = df_2019.columns)
missing_index = df_2019.index
for i in range(2018, 2012, -1):
  df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/{}/Census-validBG.csv'.format(str(i))).dropna()
  df.index = df['BLOCKGROUP_ID']
  alternative_data = df.loc[df.index.isin(missing_index)]

  alternative_data = alternative_data[(alternative_data > 0).sum(1) > 10]
  df_2019_alt = pd.concat([df_2019_alt, alternative_data])
  # display(alternative_data)
  missing_index = [x for x in missing_index if x not in alternative_data.index]
  print('{}: substituted {} Block Groups\' Missing Data'.format(str(i), len(alternative_data)))
  if len(df_2019_alt) >= len(df_2019):
    break
  # break
df_2019_alt = df_2019_alt.drop_duplicates()
print('Remaining: ' ,  len(df_2019) - len(df_2019_alt))

# %%
df_2019_valid = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019/Census-validBG.csv')
df_2019_valid.index = df_2019_valid['BLOCKGROUP_ID']
df_2019_valid = pd.concat([df_2019_valid, df_2019_alt])

# %%
is_NaN = df_2019_valid.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = df_2019_valid[row_has_NaN]

print(rows_with_NaN)

# %%
remaining_df = df_2019.loc[missing_index]
(remaining_df==0).sum(1)
discarded = remaining_df[((remaining_df <= 0).sum(1) >= 12) |  (remaining_df['Median income']<=0)]

# remaining_df = remaining_df[((remaining_df <= 0).sum(1) < 10) & (remaining_df['Median income']>0)]
remaining_df = remaining_df[((remaining_df <= 0).sum(1) < 12) & (remaining_df['Median income']>0)]

print('Keep {} records for Recovery, discarding {} because of too much incomplete information'.format(len(remaining_df), len(discarded)))
# Out:
# Keep 36 records for Recovery, discarding 18 because of too much incomplete information
# time: 11.8 ms (started: 2021-03-10 07:18:50 +00:00)

# %%
remaining_df

# %%
discarded

# %%
input()

# %%
remaining_df

# %%
len(df_2019_valid)

# %%
df_2019_valid.to_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019/Census_validBG_fixed.csv', index = False)
remaining_df.to_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019/Census_corruptBG_v2.csv', index = False)
# Out:
# time: 1.04 s (started: 2021-03-10 07:19:25 +00:00)

# %%
input()

# %%
# !cp /content/data/Census/465/2019/Census_validBG_fixed.csv "/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019"

# %% [markdown]
# ## Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
import numpy as np 
import pandas as pd
df_2019_valid = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019/Census_validBG_fixed.csv')
df = df_2019_valid.drop(['BLOCKGROUP_ID'], axis = 1).reset_index(drop=True).astype(int)
# df = df_2019_valid.drop(['BLOCKGROUP_ID', 'Median home value'], axis = 1).reset_index(drop=True)

df.describe(include = 'all')

# %%
population_mean = df['Total population'].mean()
population_mean

ignored_columns = ['Families considered in poverty calculation', 
                   'Individuals considered in poverty calculation', 
                   'Households considered in poverty calculation', 
                   'Families with income below poverty', 
                   'Individuals with income below poverty', 'Number of Households', 'No schooling completed',
                   'High school diploma',	'Bachelor\'s degree',	'Master\'s degree','Doctorate degree']


bin_labels_5 = ['Low', 'Medium_Low', 'Medium', 'Medium_High', 'High']

df_normalized = df.copy().drop(ignored_columns, axis = 1)
# df_normalized['Total population'] = df_normalized['Total population']/df_normalized['Total population'].mean()
# df_normalized['Median income'] = df_normalized['Median income']/df_normalized['Median income'].mean()
# df_normalized['Median home value'] = df_normalized['Median home value']/df_normalized['Median home value'].mean()
# df_normalized.loc[:, "Total population age 25+ years with a bachelor's degree or higher" : 'Hispanic or Latino'] = df_normalized.loc[:, "Total population age 25+ years with a bachelor's degree or higher" : 'Hispanic or Latino'].div(df['Total population'], axis = 0)
# df_normalized.loc[:, "Total Vacant" : 'Total Renter Occupied'] = df_normalized.loc[:, "Total Vacant" : 'Total Renter Occupied'].div(df['Number of Households'], axis = 0)
# df_normalized.loc[:, 'Households with income below poverty'] = df_normalized.loc[:, 'Households with income below poverty'] .div(df['Households considered in poverty calculation'], axis = 0)

# df_normalized['Median home value (range)'] = pd.qcut(df_normalized['Median income'], q=5, precision = 0)

df_normalized['Median home value (range)'] = pd.qcut(df_normalized['Median home value'],q=[0, .2, .4, .6, .8, 1],labels=[x for x in range(1, len(bin_labels_5)+1)])
df_normalized['Median home value (range)'].value_counts()

# %%
import scipy.stats
scipy.stats.pearsonr(df['Median income'].values, df['Households with income below poverty'])

# %%
df_normalized['Median income'].values

# %%
df_X = df_normalized.drop(['Median home value', 'Total Vacant', 'Total Renter Occupied', 'Median income', 'Median home value (range)'], axis = 1).reset_index(drop=True)
# df_X = df_normalized.drop(['Median home value', 'Total Vacant', 'Total Renter Occupied'], axis = 1).reset_index(drop=True)

# df_X = df_normalized[['Total population', 'Households with income below poverty', 'Total population age 25+ years with a bachelor\'s degree or higher', 'White alone', 'Black or African American alone', 'Median income']]
# df_X = df_normalized[['Households with income below poverty', 'Total population age 25+ years with a bachelor\'s degree or higher', 'White alone','Black or African American alone' ]]


df_X

# %%
from sklearn.model_selection import train_test_split
X = df_X
y = df_normalized['Median home value'].reset_index(drop=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])
coeff_df

# %%
X,y

# %%
input()

# %%
y_pred = regressor.predict(X_test)
test_df = pd.DataFrame({'Actual Median Home Value': y_test, 'Predicted': y_pred}).astype(int)
test_df.head(10)

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %%
X_missing = remaining_df.drop(['BLOCKGROUP_ID', 'Median home value'], axis = 1).reset_index(drop=True)
X_missing

# %%
remaining_df['Median home value'] = regressor.predict(X_missing).astype(int)
remaining_df

# %%
df_2019_valid = pd.concat([df_2019_valid, remaining_df])
df_2019_valid

# %%
df_2019_valid.columns = df_2019_valid.columns[:-1].tolist() + ['Number of Households']
remaining_df.columns =df_2019_valid.columns
df_2019_valid.head()

# %%
df_2019_valid.columns[:-1].tolist() + ['Number of Households']

# %%
remaining_df.to_csv('data/Census/465/2019/Census_corruptBG_fixed.csv', index = False)
df_2019_valid.to_csv('data/Census/465/2019/Census_validBG_fixed.csv', index = False)

# %%
# !cp /content/data/Census/2019/Census_validBG_fixed.csv "/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/2019"
# !cp /content/data/Census/2019/Census_corruptBG_fixed.csv "/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/2019"

# %%
# !cp -r data/Census/465 "/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/"

# %% [markdown]
# ## Neural Network (Pytorch)

# %%
pip install diffprivlib
# Out:
# ...
#      |████████████████████████████████| 81kB 4.2MB/s eta 0:00:011
# ...
#   Created wheel for diffprivlib: filename=diffprivlib-0.4.1-cp37-none-any.whl size=153526 sha256=6599fefb545bda98a6fd2aa03ed2af6d078ae075359b0caa2946bc933b365830
#   Stored in directory: /root/.cache/pip/wheels/76/55/d3/be3c4635eecedcf48e196272b356c2b3bd11460962fc952e1b
# Successfully built diffprivlib
# ...
# time: 4.93 s (started: 2021-03-13 09:08:50 +00:00)

# %%
import numpy as np 
import pandas as pd
df_2019_valid = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019/Census_validBG_fixed.csv')
df_2019_missing = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019/Census_corruptBG_v2.csv')
df = df_2019_valid.drop(['BLOCKGROUP_ID'], axis = 1).reset_index(drop=True).astype(int)
# df = df_2019_valid.drop(['BLOCKGROUP_ID', 'Median home value'], axis = 1).reset_index(drop=True)

df.describe(include = 'all')
# Out:
#        Total population  Median income  ...  Master's degree  Doctorate degree
# count       4452.000000    4452.000000  ...      4452.000000       4452.000000
# mean        1358.688455   57437.021339  ...        75.855571         11.655660
# std          837.501742   29582.457041  ...        92.746103         23.608976
# min          100.000000    6008.000000  ...         0.000000          0.000000
# 25%          799.000000   38393.000000  ...        17.000000          0.000000
# 50%         1132.000000   51188.500000  ...        43.000000          0.000000
# 75%         1699.000000   68686.000000  ...        97.250000         14.000000
# max        12146.000000  250001.000000  ...       963.000000        236.000000
#
# [8 rows x 26 columns]
# time: 4.46 s (started: 2021-03-25 07:57:55 +00:00)

# %%
population_mean = df['Total population'].mean()
population_mean

ignored_columns = [
                   'Families considered in poverty calculation', 
                   'Individuals considered in poverty calculation', 
                   'Households considered in poverty calculation', 
                   'Families with income below poverty', 
                   'Individuals with income below poverty', 'Number of Households', 'No schooling completed',
                   'High school diploma',	'Bachelor\'s degree',	'Master\'s degree','Doctorate degree', 'Total population 25 or older']
df_normalized = df.copy().drop(ignored_columns, axis = 1).astype(np.float32)
df_normalized.loc[:, "Total population age 25+ years with a bachelor's degree or higher" : 'Hispanic or Latino'] = df_normalized.loc[:, "Total population age 25+ years with a bachelor's degree or higher" : 'Hispanic or Latino'].div(df['Total population'], axis = 0)
df_normalized.loc[:, "Total Vacant" : 'Total Renter Occupied'] = df_normalized.loc[:, "Total Vacant" : 'Total Renter Occupied'].div(df['Number of Households'], axis = 0)
df_normalized.loc[:, 'Households with income below poverty'] = df_normalized.loc[:, 'Households with income below poverty'] .div(df['Households considered in poverty calculation'], axis = 0)

# df_normalized['Median home value (range)'] = pd.qcut(df_normalized['Median home value'],q=10,labels=[x for x in range(1, 11)])



X = df_normalized.drop(['Median home value'], axis = 1).reset_index(drop=True)
y = df_normalized[['Median home value']]/100000
Z = df_2019_missing.drop(ignored_columns + ['Median home value', 'BLOCKGROUP_ID'], axis = 1).astype(np.float32)
Z = Z[(Z >= 0).all(1)]
display(Z)


# X = df_normalized[['Median income']]/100000
# y = df_normalized[['Median income']]/100000
# Z = df_2019_missing[['Median income']]/100000
df_normalized
# Out:
#     Total population  ...  Households with income below poverty
# 0              887.0  ...                                 191.0
# 1             2337.0  ...                                 777.0
# 2             1736.0  ...                                 269.0
# 3              780.0  ...                                 202.0
# 4              187.0  ...                                   8.0
# 5              893.0  ...                                 189.0
# 6              625.0  ...                                  68.0
# 7              270.0  ...                                  86.0
# 8             3271.0  ...                                 358.0
# 9              750.0  ...                                 134.0
# 10            1894.0  ...                                 364.0
# 11             428.0  ...                                  62.0
# 12            1293.0  ...                                 315.0
# 13            1016.0  ...                                  82.0
# ...

# %%
y

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
# from diffprivlib.models import StandardScaler as DPStandardScaler
# Out:
# time: 4.77 ms (started: 2021-03-25 08:01:10 +00:00)

# %%
# Train - Test
X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, test_size=0.2, random_state=69)
# Split train" into train-val
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.1, random_state=21)
# Out:
# time: 9.04 ms (started: 2021-03-25 07:58:08 +00:00)

# %%
scaler_X = StandardScaler()
X_train = scaler_X.fit_transform(X_train)
X_val = scaler_X.transform(X_val)
X_test = scaler_X.transform(X_test)
Z_test = scaler_X.transform(Z)
scaler_y = MinMaxScaler()
# scaler_y = RobustScaler()
# y_train = scaler_y.fit_transform(y_train)
# y_val = scaler_y.transform(y_val)
# y_test = scaler_y.transform(y_test)

X_train = scaler_X.fit_transform(X_train)
X_val = scaler_X.transform(X_val)

X_train, y_train = np.array(X_train), np.array(y_train)
X_val, y_val = np.array(X_val), np.array(y_val)
X_test, y_test = np.array(X_test), np.array(y_test)
# Out:
# time: 13.9 ms (started: 2021-03-25 07:58:49 +00:00)

# %%
StandardScaler
# Out:
# sklearn.preprocessing._data.StandardScaler
# time: 1.96 ms (started: 2021-03-25 07:58:53 +00:00)

# %%
X_train[0].shape
# Out:
# (13,)
# time: 3.39 ms (started: 2021-03-25 07:58:54 +00:00)

# %%
class RegressionDataset(Dataset):
    
    def __init__(self, X_data, y_data):
        self.X_data = X_data
        self.y_data = y_data
        
    def __getitem__(self, index):
        return self.X_data[index], self.y_data[index]
        
    def __len__ (self):
        return len(self.X_data)
train_dataset = RegressionDataset(torch.from_numpy(X_train).float(), torch.from_numpy(y_train).float())
val_dataset = RegressionDataset(torch.from_numpy(X_val).float(), torch.from_numpy(y_val).float())
test_dataset = RegressionDataset(torch.from_numpy(X_test).float(), torch.from_numpy(y_test).float())
unseen_dataset = RegressionDataset(torch.from_numpy(Z_test).float(), torch.from_numpy(y_test).float())
# Out:
# time: 7.52 ms (started: 2021-03-25 07:58:54 +00:00)

# %%
EPOCHS = 100
BATCH_SIZE = 64
LEARNING_RATE = 0.0001
NUM_FEATURES = len(X.columns)
# NUM_FEATURES = 1
# Out:
# time: 2.08 ms (started: 2021-03-25 07:58:54 +00:00)

# %%
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=1)
test_loader = DataLoader(dataset=test_dataset, batch_size=1)
unseen_loader = DataLoader(dataset=unseen_dataset, batch_size=1)
# Out:
# time: 2.48 ms (started: 2021-03-25 07:58:55 +00:00)

# %%
# class MultipleRegression(nn.Module):
#     def __init__(self, num_features):
#         super(MultipleRegression, self).__init__()
#         self.layer_1 = nn.Linear(num_features, 32)
#         self.layer_2 = nn.Linear(32, 64)
#         self.layer_3 = nn.Linear(64, 128)
#         self.layer_4 = nn.Linear(128, 256)
#         self.layer_5 = nn.Linear(256, 256)
#         self.layer_6 = nn.Linear(256, 128)
#         self.layer_7 = nn.Linear(128, 64)
#         self.layer_8 = nn.Linear(64, 32)
#         self.layer_9 = nn.Linear(32, 16)
#         self.layer_out = nn.Linear(16, 1)
#         self.relu = nn.ReLU()
#         self.relu2 = nn.LeakyReLU()

#     def forward(self, inputs):
#       x = self.relu(self.layer_1(inputs))
#       x = self.relu2(self.layer_2(x))
#       x = self.relu(self.layer_3(x))
#       x = self.relu2(self.layer_4(x))
#       x = self.relu(self.layer_5(x))
#       x = self.relu2(self.layer_6(x))
#       x = self.relu(self.layer_7(x))
#       x = self.relu2(self.layer_8(x))
#       x = self.relu(self.layer_9(x))
#       x = self.layer_out(x)
#       return (x)
#     def predict(self, test_inputs):
#       x = self.relu(self.layer_1(test_inputs))
#       x = self.relu2(self.layer_2(x))
#       x = self.relu(self.layer_3(x))
#       x = self.relu2(self.layer_4(x))
#       x = self.relu(self.layer_5(x))
#       x = self.relu2(self.layer_6(x))
#       x = self.relu(self.layer_7(x))
#       x = self.relu2(self.layer_8(x))
#       x = self.relu(self.layer_9(x))
#       x = self.layer_out(x)
#       return (x)


class ClassiRegression(nn.Module):
    def __init__(self, num_features):
        super(MultipleRegression, self).__init__()
        
        self.layer_1 = nn.Linear(num_features, 16)
        self.layer_2 = nn.Linear(16, 32)
        self.layer_3 = nn.Linear(32, 16)
        self.layer_out1 = nn.Linear(16, 1)
        self.layer_out2 = nn.Linear(16, 1)
        
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()
    def forward(self, inputs):
            x = self.relu(self.layer_1(inputs))
            x = self.relu(self.layer_2(x))
            x1 = self.relu(self.layer_3(x))
            x2 = self.sigmoid(self.layer_3(x))
            output_1 = self.layer_out1(x1)
            output_2 = self.layer_out2(x2)
            return output_1, output_2
    def predict(self, test_inputs):
            x = self.relu(self.layer_1(test_inputs))
            x = self.relu(self.layer_2(x))
            x = self.relu(self.layer_3(x))
            output_1 = self.layer_out1(x)
            output_2 = self.layer_out2(x)
            return output_1, output_2
# Out:
# time: 59 ms (started: 2021-03-25 07:58:57 +00:00)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
model = MultipleRegression(NUM_FEATURES)
model.to(device)
print(model)
criterion = nn.MSELoss()
# criterion = nn.L1Loss()

optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
# Out:
# cuda:0
# MultipleRegression(
#   (layer_1): Linear(in_features=13, out_features=32, bias=True)
#   (layer_2): Linear(in_features=32, out_features=64, bias=True)
#   (layer_3): Linear(in_features=64, out_features=128, bias=True)
#   (layer_4): Linear(in_features=128, out_features=256, bias=True)
#   (layer_5): Linear(in_features=256, out_features=256, bias=True)
#   (layer_6): Linear(in_features=256, out_features=128, bias=True)
#   (layer_7): Linear(in_features=128, out_features=64, bias=True)
#   (layer_8): Linear(in_features=64, out_features=32, bias=True)
#   (layer_9): Linear(in_features=32, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
#   (relu2): LeakyReLU(negative_slope=0.01)
# )
# time: 8.34 ms (started: 2021-03-25 07:58:57 +00:00)

# %%
from torchsummary import summary
summary(model, (1,13))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Linear-1                [-1, 1, 32]             448
#               ReLU-2                [-1, 1, 32]               0
#             Linear-3                [-1, 1, 64]           2,112
#          LeakyReLU-4                [-1, 1, 64]               0
#             Linear-5               [-1, 1, 128]           8,320
#               ReLU-6               [-1, 1, 128]               0
#             Linear-7               [-1, 1, 256]          33,024
#          LeakyReLU-8               [-1, 1, 256]               0
#             Linear-9               [-1, 1, 256]          65,792
#              ReLU-10               [-1, 1, 256]               0
#            Linear-11               [-1, 1, 128]          32,896
#         LeakyReLU-12               [-1, 1, 128]               0
#            Linear-13                [-1, 1, 64]           8,256
# ...

# %%
loss_stats = {
    'train': [],
    "val": []
}
print("Begin training.")
for e in tqdm(range(1, EPOCHS+1)):
    
    # TRAINING
    train_epoch_loss = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        train_loss = criterion(y_train_pred, y_train_batch)
        # print(y_train_pred, y_train_batch)
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
        loss_stats['train'].append(train_epoch_loss/len(train_loader))
        loss_stats['val'].append(val_epoch_loss/len(val_loader))                              
            
        print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f}')
# Out:
# Begin training.
# ...
# Epoch 001: | Train Loss: 3.47336 | Val Loss: 3.14938
# Epoch 002: | Train Loss: 3.20098 | Val Loss: 2.43032
# Epoch 003: | Train Loss: 1.52089 | Val Loss: 0.82341
# Epoch 004: | Train Loss: 0.84288 | Val Loss: 0.52410
# Epoch 005: | Train Loss: 0.61546 | Val Loss: 0.39055
# Epoch 006: | Train Loss: 0.47479 | Val Loss: 0.31792
# Epoch 007: | Train Loss: 0.41247 | Val Loss: 0.28675
# Epoch 008: | Train Loss: 0.37642 | Val Loss: 0.27233
# Epoch 009: | Train Loss: 0.36942 | Val Loss: 0.25581
# Epoch 010: | Train Loss: 0.34612 | Val Loss: 0.23291
# Epoch 011: | Train Loss: 0.33375 | Val Loss: 0.24206
# Epoch 012: | Train Loss: 0.32890 | Val Loss: 0.22020
# Epoch 013: | Train Loss: 0.31895 | Val Loss: 0.21858
# Epoch 014: | Train Loss: 0.31940 | Val Loss: 0.21710
# Epoch 015: | Train Loss: 0.30902 | Val Loss: 0.21317
# Epoch 016: | Train Loss: 0.30962 | Val Loss: 0.21559
# Epoch 017: | Train Loss: 0.30490 | Val Loss: 0.21402
# ...

# %%
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
plt.figure(figsize=(15,8))
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable").set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')
# time: 318 ms (started: 2021-03-25 07:59:44 +00:00)

# %%
''''Testing'''
y_pred_list = []
with torch.no_grad():
    model.eval()
    for X_batch, _ in test_loader:
        X_batch = X_batch.to(device)
        y_test_pred = model(X_batch)
        y_pred_list.append(y_test_pred.cpu().numpy())
y_real = [a.squeeze().tolist() for a in y_test];
X_test_real = [a.squeeze().tolist() for a in X_test]
y_pred_list = [a.squeeze().tolist() for a in y_pred_list]

# inverse_y_real = scaler_y.inverse_transform(np.array(y_real).reshape(-1,1)).reshape(-1,)
# inverse_y_pred = scaler_y.inverse_transform(np.array(y_pred_list).reshape(-1,1)).reshape(-1,)
# pd.DataFrame(data = [inverse_y_real, inverse_y_pred]).T
pd.DataFrame(data = [X_test_real,y_real, y_pred_list]).T
# Out:
#                                                      0      1         2
# 0    [0.4910788847918411, 1.2102421978870799, 0.989...  2.722   2.34744
# 1    [-0.8394842087294158, 0.05577073425206146, -0....  0.907   1.25604
# 2    [-0.601066568442349, -0.3936851186403377, -0.9...  0.752   1.14979
# 3    [0.31166358982834125, -1.4281224658991583, -0....  1.011   1.46099
# 4    [-0.4192430144860505, -0.16053934612688234, -0...  1.961   1.44076
# ..                                                 ...    ...       ...
# 886  [-0.44573386340683574, 3.638815991422309, 2.51...  6.029   5.50533
# 887  [2.1828808272328963, -0.2636033536649002, -0.6...  1.591   1.34355
# 888  [-0.40358933103285927, 0.8232229038488175, 2.1...  1.918   2.23321
# 889  [-0.8081768418230333, -1.0710108884271938, -0....  0.763  0.815936
# 890  [0.09612440997286166, 1.2849106767750733, 0.12...  1.666   2.02431
#
# [891 rows x 3 columns]
# time: 646 ms (started: 2021-03-25 07:59:44 +00:00)

# %%
'''
Validating Training Set
'''
y_pred_list_train = []
y_real_train = []
X_train_real = []
with torch.no_grad():
    model.eval()
    for X_batch, Y_batch in train_loader:
        X_batch = X_batch.to(device)
        y_train_pred = model(X_batch)
        y_pred_list_train+=y_train_pred.cpu().squeeze().numpy().tolist()
        y_real_train+=Y_batch.cpu().squeeze().numpy().tolist()
        X_train_real+=X_batch.cpu().squeeze().numpy().tolist()
        # print(len(X_batch))
# y_real_train = [a.squeeze().tolist() for a in y_train];
# y_pred_list_train = [a.squeeze().tolist() for a in y_pred_list_train]
display(pd.DataFrame(data = [X_train_real,y_real_train, y_pred_list_train]).T)


'''
Validating Validation Set
'''
y_pred_list_val = []
with torch.no_grad(): 
    model.eval()
    for X_batch, _ in val_loader:
        X_batch = X_batch.to(device)
        y_val_pred = model(X_batch)
        y_pred_list_val.append(y_val_pred.cpu().numpy())
        # print(len(X_batch))

y_real_val = [a.squeeze().tolist() for a in y_val];
X_val_real = [a.squeeze().tolist() for a in X_val]
y_pred_list_val = [a.squeeze().tolist() for a in y_pred_list_val]
pd.DataFrame(data = [X_val_real,y_real_val, y_pred_list_val]).T
# Out:
#                                                       0      1         2
# 0     [0.18522998690605164, -0.724014163017273, -0.7...  1.569   0.92244
# 1     [-0.23862358927726746, -0.32405728101730347, -...  0.986    1.1849
# 2     [1.0425702333450317, 0.9952426552772522, 1.047...  1.816   2.21549
# 3     [1.0678569078445435, -0.1956557035446167, -0.3...  1.306   1.40058
# 4     [-0.23380707204341888, -0.9857571125030518, -0...  0.594   0.83061
# ...                                                 ...    ...       ...
# 3199  [-0.47102057933807373, -0.5197007656097412, -0...  0.996   1.08234
# 3200  [2.209371566772461, 1.1339607238769531, 0.3716...  2.726   2.00542
# 3201  [-0.9382228255271912, 0.050730109214782715, -0...  1.302   1.15405
# 3202  [-0.6167202591896057, -1.1116046905517578, -1....  0.546  0.550517
# 3203  [-0.5721674561500549, -0.5873795747756958, -0....  0.817  0.985903
#
# [3204 rows x 3 columns]
# ...

# %%
mse = mean_squared_error(y_real_train, y_pred_list_train)
r_square = r2_score(y_real_train, y_pred_list_train)
print('Mean Absolute Error:', mean_absolute_error(y_real_train, y_pred_list_train))
print("Mean Squared Error (Train) :",mse)
print("R^2 :",r_square)

mse = mean_squared_error(y_val, y_pred_list_val)
r_square = r2_score(y_val, y_pred_list_val)
print('Mean Absolute Error:', mean_absolute_error(y_val, y_pred_list_val))
print("Mean Squared Error (Val) :",mse)
print("R^2 :",r_square)

mse = mean_squared_error(y_test, y_pred_list)
r_square = r2_score(y_test, y_pred_list)
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred_list))
print("Mean Squared Error (Test) :",mse)
print("R^2 :",r_square)
# Out:
# Mean Absolute Error: 0.3061057712799043
# Mean Squared Error (Train) : 0.22423949790393574
# R^2 : 0.795200065765256
# Mean Absolute Error: 0.2837970191403931
# Mean Squared Error (Val) : 0.17817410158181196
# R^2 : 0.7919235364634445
# Mean Absolute Error: 0.3143021127185008
# Mean Squared Error (Test) : 0.20333037347572458
# R^2 : 0.7795132273470008
# time: 18.2 ms (started: 2021-03-25 08:01:14 +00:00)

# %%
z_pred_list = []
with torch.no_grad():
    model.eval()
    for Z_batch, _ in unseen_loader:
        Z_batch = Z_batch.to(device)
        z_test_pred = model(Z_batch)
        z_pred_list.append(z_test_pred.cpu().numpy())

z_pred_list = [a.squeeze().tolist() for a in z_pred_list]
inverse_z_pred = scaler_y.inverse_transform(np.array(z_pred_list).reshape(-1,1)).reshape(-1,)
pd.DataFrame(data = [inverse_z_pred]).T
temp = df_2019_missing[df_2019_missing.index.isin(Z.index)]
temp['Median home value'] = inverse_z_pred
temp

# %%
df_2019_fixed = pd.concat([df_2019_valid, temp], axis = 0).reset_index(drop=True).astype(int)
df_2019_fixed

# %%
len(df_2019_fixed) - len(df_2019_valid)

# %%
y_train[:10], y_pred_list_train[:10]

# %%
df_2019_fixed.to_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019/Census_validBG_fixed_withNN.csv', index = False)

# %% [markdown]
# ## Automate DP Values

# %%
epsilons = np.logspace(-2, 2, 100)
epsilons
# Out:
# array([1.00000000e-02, 1.09749877e-02, 1.20450354e-02, 1.32194115e-02,
#        1.45082878e-02, 1.59228279e-02, 1.74752840e-02, 1.91791026e-02,
#        2.10490414e-02, 2.31012970e-02, 2.53536449e-02, 2.78255940e-02,
#        3.05385551e-02, 3.35160265e-02, 3.67837977e-02, 4.03701726e-02,
#        4.43062146e-02, 4.86260158e-02, 5.33669923e-02, 5.85702082e-02,
#        6.42807312e-02, 7.05480231e-02, 7.74263683e-02, 8.49753436e-02,
#        9.32603347e-02, 1.02353102e-01, 1.12332403e-01, 1.23284674e-01,
#        1.35304777e-01, 1.48496826e-01, 1.62975083e-01, 1.78864953e-01,
#        1.96304065e-01, 2.15443469e-01, 2.36448941e-01, 2.59502421e-01,
#        2.84803587e-01, 3.12571585e-01, 3.43046929e-01, 3.76493581e-01,
#        4.13201240e-01, 4.53487851e-01, 4.97702356e-01, 5.46227722e-01,
#        5.99484250e-01, 6.57933225e-01, 7.22080902e-01, 7.92482898e-01,
#        8.69749003e-01, 9.54548457e-01, 1.04761575e+00, 1.14975700e+00,
# ...

# %%
from tqdm.notebook import tqdm
R2_df = pd.DataFrame(columns = ['epsilon', 'R2'])

for epsilon in tqdm(epsilons):
  # Train - Test
  X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, test_size=0.2, random_state=69)
  # Split train" into train-val
  X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.1, random_state=21)

  scaler_X = StandardScaler()
  X_train = scaler_X.fit_transform(X_train)
  X_val = scaler_X.transform(X_val)
  X_test = scaler_X.transform(X_test)
  Z_test = scaler_X.transform(Z)
  scaler_y = MinMaxScaler()

  scaler_X = DPStandardScaler(epsilon=epsilon)
  X_train = scaler_X.fit_transform(X_train)
  X_val = scaler_X.transform(X_val)

  X_train, y_train = np.array(X_train), np.array(y_train)
  X_val, y_val = np.array(X_val), np.array(y_val)
  X_test, y_test = np.array(X_test), np.array(y_test)

  train_dataset = RegressionDataset(torch.from_numpy(X_train).float(), torch.from_numpy(y_train).float())
  val_dataset = RegressionDataset(torch.from_numpy(X_val).float(), torch.from_numpy(y_val).float())
  test_dataset = RegressionDataset(torch.from_numpy(X_test).float(), torch.from_numpy(y_test).float())
  unseen_dataset = RegressionDataset(torch.from_numpy(Z_test).float(), torch.from_numpy(y_test).float())

  train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)
  val_loader = DataLoader(dataset=val_dataset, batch_size=1)
  test_loader = DataLoader(dataset=test_dataset, batch_size=1)
  unseen_loader = DataLoader(dataset=unseen_dataset, batch_size=1)

  device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

  model = MultipleRegression(NUM_FEATURES)
  model.to(device)

  criterion = nn.MSELoss()


  optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
  loss_stats = {
      'train': [],
      "val": []
  }
  print("Begin training with Epsilon {}".format(epsilon))
  for e in tqdm(range(1, 100+1)):
      
      # TRAINING
      train_epoch_loss = 0
      model.train()
      for X_train_batch, y_train_batch in train_loader:
          X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
          optimizer.zero_grad()
          
          y_train_pred = model(X_train_batch)
          train_loss = criterion(y_train_pred, y_train_batch)
          # print(y_train_pred, y_train_batch)
          train_loss.backward()
          optimizer.step()
          
          train_epoch_loss += train_loss.item()
          
          
      # VALIDATION    
      with torch.no_grad():
          
          val_epoch_loss = 0
          
          model.eval()
          for X_val_batch, y_val_batch in val_loader:
              X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
              
              y_val_pred = model(X_val_batch)
                          
              val_loss = criterion(y_val_pred, y_val_batch)
              
              val_epoch_loss += val_loss.item()
          loss_stats['train'].append(train_epoch_loss/len(train_loader))
          loss_stats['val'].append(val_epoch_loss/len(val_loader))                              
              
          print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f}')

  ''''Testing'''
  y_pred_list = []
  with torch.no_grad():
      model.eval()
      for X_batch, _ in test_loader:
          X_batch = X_batch.to(device)
          y_test_pred = model(X_batch)
          y_pred_list.append(y_test_pred.cpu().numpy())
  y_real = [a.squeeze().tolist() for a in y_test];
  X_test_real = [a.squeeze().tolist() for a in X_test]
  y_pred_list = [a.squeeze().tolist() for a in y_pred_list]

  mse = mean_squared_error(y_test, y_pred_list)
  r_square = r2_score(y_test, y_pred_list)
  print("Mean Squared Error (Test) :",mse)
  print("R^2 :",r_square)
  new_row = pd.DataFrame([[epsilon, r_square]], columns = ['epsilon', 'R2'])
  R2_df = R2_df.append(new_row, ignore_index = True)
  R2_df.to_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019/DP_R2_Testing.csv', index = False)

  # break
R2_df.to_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019/DP_R2_Testing.csv', index = False)
R2_df
# Out:
# ...
# Begin training with Epsilon 0.01
# /usr/local/lib/python3.7/dist-packages/diffprivlib/models/standard_scaler.py:217: PrivacyLeakWarning: Range parameter hasn't been specified, so falling back to determining range from the data.
# This will result in additional privacy leakage.  To ensure differential privacy with no additional privacy loss, specify `range` for each valued returned by np.mean().
#   PrivacyLeakWarning)
# ...
# Epoch 001: | Train Loss: 2.57153 | Val Loss: 2.20858
# Epoch 002: | Train Loss: 1.88307 | Val Loss: 0.85798
# Epoch 003: | Train Loss: 1.04813 | Val Loss: 0.78843
# Epoch 004: | Train Loss: 1.01773 | Val Loss: 0.76839
# Epoch 005: | Train Loss: 0.99696 | Val Loss: 0.74429
# Epoch 006: | Train Loss: 0.98569 | Val Loss: 0.72691
# Epoch 007: | Train Loss: 0.96401 | Val Loss: 0.70978
# Epoch 008: | Train Loss: 0.96440 | Val Loss: 0.68855
# Epoch 009: | Train Loss: 0.92530 | Val Loss: 0.66783
# Epoch 010: | Train Loss: 0.90521 | Val Loss: 0.63057
# ...

# %%
  ''''Testing'''
  y_pred_list = []
  with torch.no_grad():
      model.eval()
      for X_batch, _ in test_loader:
          X_batch = X_batch.to(device)
          y_test_pred = model(X_batch)
          y_pred_list.append(y_test_pred.cpu().numpy())
  y_real = [a.squeeze().tolist() for a in y_test];
  X_test_real = [a.squeeze().tolist() for a in X_test]
  y_pred_list = [a.squeeze().tolist() for a in y_pred_list]
# Out:
# time: 904 ms (started: 2021-03-13 19:34:27 +00:00)

# %%
y_pred_list[:10]
# Out:
# [15.318878173828125,
#  5.883804798126221,
#  2.852536916732788,
#  4.046481609344482,
#  6.486425876617432,
#  0.7191988825798035,
#  2.272972345352173,
#  2.2042315006256104,
#  2.4329397678375244,
#  2.1339714527130127]
# time: 3.97 ms (started: 2021-03-13 19:37:48 +00:00)

# %%
pd.DataFrame([[0.01, 0.2]], columns = ['epsilon', 'R2'])
# Out:
#    epsilon   R2
# 0     0.01  0.2
# time: 15.7 ms (started: 2021-03-13 09:44:06 +00:00)

# %% [markdown]
# # Filter BGs down to 465

# %%
import pandas as pd
df_2019_fixed = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019/Census_validBG_fixed_withNN.csv')
BG_df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/311_Block_Group_Processed.csv')
display(BG_df.head())
TARGET_BGS = BG_df['block_id'].dropna().astype(int).unique().tolist()
TARGET_BGS

# %%
df_465BG = df_2019_fixed[df_2019_fixed.BLOCKGROUP_ID.isin(TARGET_BGS)].reset_index(drop=True)
[x for x in TARGET_BGS if x not in temp.BLOCKGROUP_ID.values.tolist()]
# len(df_465BG)

# %%
df_465BG.to_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019/465_BG.csv', index=False)

# %% [markdown]
# # **Shape Extraction (Census)**

# %%
# !mkdir data/
# !cp "/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census-blockgroups_2010_20000_convert.json" /content/data/

# %%
import json
with open('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Archives/Census-blockgroups_2010_20000_convert.json') as f:
  annotations = json.load(f)
# annotations

# %%
annotations

# %%
len(annotations['features'])

# %%
# annotations['features'][0]['properties']['description']
valid_bg = df_465BG.BLOCKGROUP_ID.astype(str)
shape_list = []
for bg in valid_bg:
  for ann in annotations['features']:
    description = ann['properties']['description']
    GEO_ID_idx = description.find('GEOID10')
    GEO_ID = description[GEO_ID_idx+18: GEO_ID_idx+30]
    # print(GEO_ID, bg)

    if GEO_ID == bg:
      polygon = [[x[1], x[0]] for x in ann['geometry']['coordinates'][0][0]]
      # print(polygon)
      shape_list.append(polygon)
    # display(df_2019_valid[df_2019_valid.index == int(GEO_ID)])
  # break
df_465BG['Boundaries'] = shape_list
df_465BG

# %%
shape_list

# %%
df_465BG

# %%
df_465BG.to_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019/Census_validBG_withshapes.csv', index = False)

# %% [markdown]
# # Map NBH and BG

# %% [markdown]
# ```
# '''
# Merged 311 Calls by Case ID
# '''
# import pandas as pd
# df_311_nbh = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/311_call_2007_2020_Neighborhood.csv')
# df_311_bg = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/311_Block_Group_Processed.csv')[['CASE ID', 'block_id']]
# df_311_bg.columns = ['CASE ID', 'BLOCKGROUP ID']
# df_311_bg.head()
# df_311 = df_311_nbh.merge(df_311_bg, how='inner', left_on='CASE ID', right_on='CASE ID')#.drop(columns=['Neighborhood Number'])
# df_311.head()
# df_311.to_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/311_Calls_2007-2020.csv', index=False)
#
# ```

# %%
import pandas as pd
socio_df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/311_Calls_2007-2020.csv')
display(socio_df.head())
df_2019_valid = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/465/2019/Census_validBG_withshapes.csv")
display(df_2019_valid.head())

# %%
# sample_df = socio_df.sample(n=10000, random_state=1).reset_index(drop=True).copy()
sample_df = socio_df.copy()

# %% [markdown]
# ## Shape Extraction (NBH)

# %%
NBHgroup_df = sample_df.groupby(['nbh_id', 'nbh_name', 'BLOCKGROUP ID']).size().to_frame('value')

NBHgroup_df.reset_index(inplace=True)
NBHgroup_df.set_index('nbh_id')
NBHgroup_df = NBHgroup_df.drop('value', axis = 1)
NBH_BG_dict = {k: {'BLOCKGROUPS': []} for k in NBHgroup_df['nbh_id'].unique()}
for index, row in NBHgroup_df.iterrows():
  NBH_BG_dict[row['nbh_id']]['BLOCKGROUPS'].append(str(int(row['BLOCKGROUP ID'])))
  NBH_BG_dict[row['nbh_id']]['nbh_name'] = row['nbh_name']

for k in NBH_BG_dict:
  NBH_BG_dict[k]['BLOCKGROUPS'] = list(set(NBH_BG_dict[k]['BLOCKGROUPS']))

NBH_BG_dict

# %%
NBHgroup_df

# %%
import json
TARGET_NBH_IDs = NBH_BG_dict.keys()

with open('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Kansas City Neighborhood Boundaries.geojson') as f:
  nbh_info = json.load(f)

TARGET_NBH_INFO = []
for nbh in nbh_info['features']:
  nbhid = int(nbh['properties']['nbhid'])
  # print(nbhid)
  if nbhid in TARGET_NBH_IDs:
    # print(nbh)
    polygons = nbh['geometry']['coordinates'][0][0]
    TARGET_NBH_INFO.append(polygons)
    NBH_BG_dict[nbhid]['Boundaries'] = polygons
  # break
NBH_BG_dict

# %%
NBH_BG_dict[1]

# %% [markdown]
# ## Calculate NBH's Socio-economic Metrics from BG using Mean

# %%
socio_df = pd.DataFrame()
for k, v in NBH_BG_dict.items():
  BG_list = v['BLOCKGROUPS']
  boundaries = v['Boundaries']
  nbh_name = v['nbh_name']
  mean_df = df_2019_valid[df_2019_valid['BLOCKGROUP_ID'].isin(BG_list)].dropna()
  if len(mean_df > 0):
    mean_df = mean_df.loc[:,'Total population':'Doctorate degree'].mean().to_frame(k).astype(int).T
    mean_df['NBH_ID'] = [k]
    mean_df['NBH_NAME'] = [nbh_name]
    mean_df['EQUIVALENT_BLOCKGROUPS'] = str(BG_list)
    mean_df['NBH_BOUNDARIES'] = str(boundaries)
    new_cols = mean_df.columns.tolist(); new_cols.insert(0, new_cols.pop(new_cols.index('NBH_ID')))
    # print(new_cols)
    mean_df = mean_df.loc[:, new_cols]
    socio_df =  pd.concat([socio_df, mean_df], axis = 0)
  else:
    print(BG_list, k, nbh_name)
  # break
# socio_df.to_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/241NBH_socioeconomic_withshapes.csv', index = False)
display(socio_df.head())
print(len(socio_df))

# %%
BG_list

# %% [markdown]
# # Connect with Crime Data

# %%
import pandas as pd
df_crime = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Crime/KCPD_Crime_Data_2020.csv')

# %%
df_temp = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Crime/temp.csv')
temp = df_temp['Address'] +  ', ' + df_temp['City'] #+ ', ' +  df_crime['Zip Code'].fillna('').astype(str)
TEMP_ADDRESSES = temp.unique().tolist()
df_temp.head()

# %%
REMAINING_ADDRESSES = [x for x in TARGET_ADDRESSES if x not in TEMP_ADDRESSES]
len(REMAINING_ADDRESSES)

# %%
address_dict = {}
for index, row in df_temp.iterrows():
  TARGET_ADDRESS = '{}, {}'.format(row['Address'],row['City'])
  # print(TARGET_ADDRESS)
  formatted_addr = row['Formatted Address']
  location = {'lat': row['lat'], 'lng': row['lng']}
  zipcode = row['Zip Code']
  address_dict[TARGET_ADDRESS] = {'formatted_addresses': formatted_addr,
                          'location': geocode_result[0]['geometry']['location'],
                          'zipcode': zipcode, 'city': row['City']}

  # break

# %%
len(df_temp)

# %%
len(address_dict)

# %% [markdown]
# ## Add Lat&Lng to Crime Data

# %%
temp = df_crime['Address'] +  ', ' + df_crime['City'] #+ ', ' +  df_crime['Zip Code'].fillna('').astype(str)
TARGET_ADDRESSES = temp.unique().tolist()

# %%
pip install -U googlemaps

# %%
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key='AIzaSyDi4YrgqSjrfFnD5Vs3PsmaDg3teg8pmdE') #fake account
# AIzaSyDi4YrgqSjrfFnD5Vs3PsmaDg3teg8pmdE
# Geocoding an address
TARGET_ADDRESS = '121 Ward Parkway, Kansas City, MO, 64112'
geocode_result = gmaps.geocode(TARGET_ADDRESS)
geocode_result

# %%
import json
from tqdm.notebook import tqdm
# address_dict = {}
invalid_addresses = []

for addr in tqdm(REMAINING_ADDRESSES):
  geocode_result = gmaps.geocode(addr)
  # print(json.dumps(geocode_result, indent=4, sort_keys=True))
  if len(geocode_result) > 0:
    formatted_addr =  geocode_result[0]['formatted_address']
    for obj in geocode_result[0]['address_components']:
      if 'postal_code' in obj['types']:
        zipcode = obj['long_name']
      if 'locality' == obj['types'][0]:
        city = obj['long_name']
    address_dict[addr] = {'formatted_addresses': formatted_addr,
                          'location': geocode_result[0]['geometry']['location'],
                          'zipcode': zipcode, 'city': city}
  else: 
    invalid_addresses.append(addr)
  # break
# len(address_dict)
# invalid_addresses

# %%
address_dict_str = json.dumps(address_dict)
with open('address_dict.json', 'w') as f:
  f.write(address_dict_str)

# %%
input()

# %%
# geocode_result[0]['formatted_address']
# geocode_result[0]['geometry']['location']
for obj in geocode_result[0]['address_components']:
  if 'postal_code' in obj['types']:
    print(obj['long_name'])

# %% [markdown]
# ## Add Localities to Crime Data

# %%
import json
from tqdm.notebook import tqdm
import requests
# lat_list = []; lng_list = []
# formatted_addr_list = []
# zipcode_list = []
result_df = pd.DataFrame()
for index, row in tqdm(df_crime[38000:].iterrows(), total = df_crime[38000:].shape[0]):
  # if index >= 38000:
    TARGET_ADDRESS = '{}, {}'.format(row['Address'],row['City'])
    if TARGET_ADDRESS in address_dict:
      # print(address_dict[TARGET_ADDRESS])
      lat, lng = address_dict[TARGET_ADDRESS]['location']['lat'], address_dict[TARGET_ADDRESS]['location']['lng']


      response = requests.get("http://nsfscc-bert.ngrok.io/getGeoLocations?latitude={}&longitude={}".format(lat,lng)).json()

      row['Zip Code'] = address_dict[TARGET_ADDRESS]['zipcode']
      row['Formatted Address'] = address_dict[TARGET_ADDRESS]['formatted_addresses']
      row['lat'] = lat; row['lng'] = lng
      row['nbh_name'] = response['nbhname']; row['nbhid'] = response['nbhid']
      row['blockgroup_id'] = response['block_id']
      row['police_division'] = response['divisionname']; row['police_division_id'] = response['division']; 
      result_df = result_df.append(row, ignore_index = True)
      if index % 1000 == 0:
        result_df.to_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Crime/temp2.csv', index=False)


    # formatted_addr_list.append(formatted_addr); lat_list.append(lat); lng_list.append(lng); zipcode_list.append(zipcode)

  # break
result_df

# %%
temp = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Crime/temp.csv')
temp1 = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Crime/temp1.csv')
temp2 = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Crime/temp2.csv')

# %%
len(temp), len(temp1), len(temp2)

# %%
df_concat = pd.concat([temp, temp1, temp2], axis = 0).drop_duplicates().reset_index(drop=True) 
# df_concat = pd.concat([temp, temp1, temp2], axis = 0).reset_index(drop=True)
df_concat = df_concat[df_concat['nbhid'].isnull() == False]
df_concat['nbhid'] = df_concat['nbhid'].astype(int).astype(str)

# %%
df_concat[df_concat['nbhid'].isnull() == False]

# %%
df_concat.to_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Crime/CrimeData2020-withlocality.csv', index = False)

# %%
df_crime.groupby('nbhid').size().to_frame('crime_records')

# %%
input()

# %% [markdown]
# # Connect with 311 & Cluster

# %%
import pandas as pd
df_311 = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/311_Calls_2007-2020.csv')
display(df_311.head())
socio_df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/240NBH_socioeconomic_withshapes.csv')
display(socio_df.head())
# Out:
#       CASE ID SOURCE  ...                   nbh_name BLOCKGROUP ID
# 0  2019207923    WEB  ...                   New Mark  2.904702e+11
# 1  2020054721    WEB  ...             Westside South  2.909500e+11
# 2  2019182182  PHONE  ...            South Hyde Park  2.909501e+11
# 3  2020149407  PHONE  ...  East Community Team South  2.909500e+11
# 4  2019184705    WEB  ...              Western 49-63  2.909501e+11
#
# [5 rows x 33 columns]
#    NBH_ID  ...                                     NBH_BOUNDARIES
# 0       1  ...  [[-94.57683939536817, 39.1095113156913], [-94....
# 1       2  ...  [[-94.57702050009627, 39.10947486858083], [-94...
# 2       3  ...  [[-94.58859268223543, 39.096400643183834], [-9...
# 3       4  ...  [[-94.57231978141229, 39.10627878158096], [-94...
# 4       5  ...  [[-94.56368874393506, 39.105292460875276], [-9...
#
# [5 rows x 30 columns]
# time: 17.7 s (started: 2021-03-27 09:46:50 +00:00)

# %%
pd.DataFrame(df_311['DEPARTMENT'].unique()).to_csv('311-Departments.csv', index=False)

# %%
# df_311[df_311['DEPARTMENT'] == 'Mayors Office']
# df_311[df_311['DEPARTMENT'] == 'NHS']

df_311[df_311['REQUEST TYPE'].str.contains('Cruelty')]
# Out:
#             CASE ID SOURCE  ...             nbh_name BLOCKGROUP ID
# 16       2020149657  PHONE  ...          Shoal Creek  2.904702e+11
# 172      2020020759  PHONE  ...   North Indian Mound  2.909502e+11
# 291      2019185284  PHONE  ...   South Indian Mound  2.909500e+11
# 464      2020117755  PHONE  ...             Davidson  2.904702e+11
# 478      2020090619  PHONE  ...      KCI & 2nd Creek  2.916503e+11
# ...             ...    ...  ...                  ...           ...
# 1495586  2020146350    WEB  ...  Eastwood Hills East  2.909501e+11
# 1495587  2020146678    WEB  ...             Fairlane  2.909501e+11
# 1495592  2020148484    WEB  ...  Eastwood Hills East  2.909501e+11
# 1495595  2020149247  PHONE  ...               Dunbar  2.909501e+11
# 1495596  2020149902  PHONE  ...             Santa Fe  2.909500e+11
#
# [14557 rows x 33 columns]
# time: 741 ms (started: 2021-03-27 09:47:08 +00:00)

# %%
# sample_df = df_311.sample(n=10000, random_state=1).reset_index(drop=True).copy()
sample_df = df_311.copy()
# sample_df = sample_df[sample_df['DAYS TO CLOSE'].notna() & sample_df['STATUS'].str.contains('RESOL')].reset_index(drop=True)
sample_df = sample_df[(sample_df['STATUS'] == 'RESOL') & (sample_df['DAYS TO CLOSE'].notna())].reset_index(drop=True)
sample_df['nbh_name'] = sample_df['nbh_name'].fillna('Unnamed')

sample_df[sample_df['nbh_id'] == 0 ]
# Out:
#             CASE ID SOURCE      DEPARTMENT  ... nbh_id nbh_name BLOCKGROUP ID
# 267      2020133518  PHONE             NHS  ...      0  Unnamed  2.909502e+11
# 660      2020088634  PHONE             NHS  ...      0  Unnamed  2.909502e+11
# 955      2020133201    WEB  Water Services  ...      0  Unnamed  2.909502e+11
# 1086     2020130833    WEB    Public Works  ...      0  Unnamed  2.909502e+11
# 1443     2019197076    WEB    Public Works  ...      0  Unnamed  2.909502e+11
# ...             ...    ...             ...  ...    ...      ...           ...
# 1463823  2020153063  PHONE    Public Works  ...      0  Unnamed  2.909502e+11
# 1464027  2020153584    WEB          Health  ...      0  Unnamed  2.909502e+11
# 1464034  2020153713    WEB          Health  ...      0  Unnamed  2.909598e+11
# 1464104  2020153325    WEB    Public Works  ...      0  Unnamed  2.909502e+11
# 1464232  2020153724  EMAIL             NHS  ...      0  Unnamed  2.909502e+11
#
# [10223 rows x 33 columns]
# ...

# %%
sample_df.head()

# %% [markdown]
# ## Group by NBH ID (to get Total Calls)

# %%
count_df = sample_df.groupby(['nbh_id']).size().to_frame('Total Calls')
count_df.head()
# Out:
#         Total Calls
# nbh_id
# 0             10223
# 1               720
# 2              2697
# 3              2995
# 4             17914
# time: 41.4 ms (started: 2021-03-27 09:47:10 +00:00)

# %% [markdown]
# ##Group By Call Category

# %%
from tqdm.notebook import tqdm
CATEGORY_MAP = {
    'City Facilities': ['City Facilities', 'City Clerks Office','City Managers Office','City Planning & Development', 'Facilities'],
    'Parking': ['Park','Park Maintenance','Parking Meter','Downtown Parking'],
    'Property Violations': ['Property / Buildings / Construction', 'Property Preservation','Property Violations', 'Graffiti', 'Property & Nuisance Violations', 'Nuisance Violations'],
    'Animals': ['Animals / Pets', 'Animal'],
    'Water': ['Water','Water Leak','Storm Water','Storm Water / Sewer','Wastewater','Water Main Break','Water Quality','Water Services','Sewer','Ditch'],
    'Trash': ['Trash / Recycling','Trash'],
    'Public Health': ['Health','Public Health','Food Protection','Air Quality','Weeds'],
    'Lights/Signals/Signs': ['Lights / Signals','Signal','Signs'],
    'Vehicles': ['Vehicle', 'Vehicles / Parking'],
    'Street/Sidewalks': ['Street', 'Street Light','Street Sign','Pothole','Sidewalk','Sidewalks / Curbs / Ditch','Streets / Roadways / Alleys','Steel Plate','Markings'],
    'Legal': ['Government','Mayors Office','Permit','Law','Municipal Court'],
    'Public Safety': ['Public Safety','Fire','Snow & Ice','Trees'],
    'Parks and Recreation': ['Parks & Recreation','Boulevard Parks and Rec'],
    'Neighborhood': ['Neighborhood & Community Services', 'Neighborhood Preservation'],
    'Data Not Available': ['Data Not Available'],
    'Information Request': ['Information Request'],
    'Maintenance': ['Maintenance','Bridge','Guard Rail','Cleaning'],
    'Traffic': ['Traffic Sign','Traffic Study'],
    'Information Technology': ['Information Technology'],
    'Noise': ['Noise Control'],
    'Other': ['Aviation','Public Works','Zoning','Right of Way','Sealing','Sweeping','Bulky Appointment',
              'Consumer Services','Convention & Entertainment Center','Finance','Housing','Mowing / Weeds','Capital Projects']
}
NEW_CATEGORIES = []
for index, row in tqdm(sample_df.iterrows(), total = sample_df.shape[0]):
  new_cat = None
  category = row['CATEGORY']
  for key, value in CATEGORY_MAP.items():
    if category in value:
      new_cat = key
      NEW_CATEGORIES.append(new_cat)
  if new_cat is None:
    print(category)
  assert new_cat is not None
  # if index == 10:
  #   break
sample_df['CATEGORY_NEW'] = NEW_CATEGORIES

# %%
'''
Group By Call Category
'''
import numpy as np
from sklearn.preprocessing import StandardScaler
call_df = sample_df.groupby(['CATEGORY_NEW', 'nbh_id']).size()
call_df = call_df.unstack(level = 0).fillna(0).astype(int) #level = 1 will swap column and row
# call_df['Total'] = call_df.sum(axis=1)#; call_df.loc['Total'] = call_df.sum()
# call_df[call_df.columns] = call_df[call_df.columns].applymap(int)

call_df_org = call_df.copy()
call_df = call_df.loc[:,"Animals":"Water"].div(call_df.sum(axis=1), axis=0)
call_df = call_df.merge(socio_df, how='inner', left_on='nbh_id', right_on='NBH_ID')#.drop(columns=['Neighborhood Number'])
call_df.index = call_df['NBH_ID']
# call_df.loc[:,"Animals":"Water"] = temp_df*100


call_df.head()

# %% [markdown]
# ## Group by Department

# %%
from tqdm.notebook import tqdm
DEPARTMENT_MAP = {
    'Parks and Recreation': ['Parks and Rec','Parks & Rec','Parks & Recreation'],
    'National Honor Society': ['NHS'],
    'National Communications System': ['NCS'],
    'Information Technology': ['Information Technology', 'IT'],
    'Water Services': ['Water Services'],
    'City Services': ['City Planning and Development','City Managers Office','Mayors Office'],
    'General Service': ['General Service'],
    'KC Police Department': ['KCPD'],
    'Finance': ['Finance'],
    'Municipal Court': ['Municipal Court'],
    'Housing and Community Development': ['Housing Community Dev'],
    'Convention and Entertainment Center': ['Convention and Entertainment Center'],
    'Public Works': ['Public Works'],
    'Fire': ['Fire'],
    'Health': ['Health'],
    'Human Resources': ['Human Resources'],
    'Other': ['Northland','Northeast','South','Aviation'],  
}
NEW_DEPARTMENTS = []
for index, row in tqdm(sample_df.iterrows(), total = sample_df.shape[0]):
  new_dept= None
  dept = row['DEPARTMENT']
  for key, value in DEPARTMENT_MAP.items():
    if dept in value:
      new_dept = key
      NEW_DEPARTMENTS.append(new_dept + ' (dept)')
  if new_dept is None:
    print(new_dept)
    display(row)
  assert new_dept is not None
  # if index == 10:
  #   break
sample_df['DEPARTMENT_NEW'] = NEW_DEPARTMENTS

# %%
'''
Group By DEPARTMENT
'''
dept_df = sample_df.groupby(['DEPARTMENT_NEW', 'nbh_id']).size()
dept_df = dept_df.unstack(level = 0).fillna(0).astype(int) #level = 1 will swap column and row
# dept_df['Total'] = dept_df.sum(axis=1)#; dept_df.loc['Total'] = dept_df.sum()
# dept_df[dept_df.columns] = dept_df[dept_df.columns].applymap(int)
dept_df_org = dept_df.copy()
dept_df = dept_df.loc[:,"City Services (dept)":"Water Services (dept)"].div(dept_df.sum(axis=1), axis=0)
dept_df = dept_df.merge(socio_df, how='inner', left_on='nbh_id', right_on='NBH_ID')#.drop(columns=['Neighborhood Number'])
dept_df.index = dept_df['NBH_ID']
# dept_df.loc[:,"Animals":"Water"] = temp_df*100

dept_df.head()

# %% [markdown]
# ##Group By Response Time

# %%
import plotly.express as px
import numpy as np
from tqdm.notebook import tqdm
RESPONSE_THRESHOLD = {
    0: 'On time (0-day delay)',
    1: '1 day',
    2: '2 days',
    7: '7-day window',
    14: '14-day window',
    30: '30-day window',
    60: '60-day window',
    90: '90-day window',
    120: '120-day window',
    180: '180-day window',
    365: '365-day window', 
    4525: '365+ -day window'
    }

# response_count_df = sample_df['DAYS TO CLOSE'].to_frame('DAYS') 
# response_count_df.head()
# counts, bins = np.histogram(response_count_df['DAYS'], bins=list(RESPONSE_THRESHOLD.keys()))
# bins = 0.5 * (bins[:-1] + bins[1:])
# fig = px.bar(x=bins, y=counts, labels={'x':'DAYS', 'y':'count'})
# fig.show()

new_days_to_close = []
for index, row in tqdm(sample_df.iterrows(), total = sample_df.shape[0]):
  old_days = row['DAYS TO CLOSE']
  temp = len(new_days_to_close)
  # print(old_days)
  for lim in RESPONSE_THRESHOLD:
    if old_days <= lim:
      # print(RESPONSE_THRESHOLD[lim])
      new_days_to_close.append(RESPONSE_THRESHOLD[lim])
      break
  if temp == len(new_days_to_close):
    display(row)
  # break
sample_df['DAYS TO CLOSE (NEW)'] = new_days_to_close
sample_df[['DAYS TO CLOSE','DAYS TO CLOSE (NEW)']].head()

# %%
'''
Group By Response Time Category
'''
response_df = sample_df.groupby(['DAYS TO CLOSE (NEW)', 'nbh_id']).size()
response_df= response_df.unstack(level = 0).fillna(0).astype(int) #level = 1 will swap column and row
response_df = response_df[RESPONSE_THRESHOLD.values()] 
# response_df.columns = response_df.columns.astype(str)
response_df_org = response_df.copy()
response_df = response_df.div(response_df.sum(axis=1), axis=0) #normalize by total number of calls
response_df = response_df.merge(socio_df, how='inner', left_on='nbh_id', right_on='NBH_ID')#.drop(columns=['block_id'])
response_df.index = response_df['NBH_ID']

response_df

# %%
socio_df

# %% [markdown]
# ##Group By Call Frequency

# %%
'''
Group By Call Frequency Category
'''
freq_df = sample_df.groupby(['nbh_id']).size().to_frame(name = 'Num of Calls')

freq_df = freq_df.merge(socio_df, how='inner', left_on='nbh_id', right_on='NBH_ID')#.drop(columns=['block_id'])
freq_df_org = freq_df.copy()
freq_df['Frequency'] = freq_df['Num of Calls'].div(freq_df['Total population'], axis=0)
freq_df.index = freq_df['NBH_ID']
freq_df.head()
# Out:
#         Num of Calls  ...  Frequency
# NBH_ID                ...
# 1                720  ...   0.472441
# 2               2697  ...   1.085312
# 3               2995  ...   3.434633
# 4              17914  ...   9.102642
# 5               2529  ...   1.613912
#
# [5 rows x 32 columns]
# time: 95 ms (started: 2021-03-27 09:47:10 +00:00)

# %%
freq_df
# Out:
#         Num of Calls  ...  Frequency
# NBH_ID                ...
# 1                720  ...   0.472441
# 2               2697  ...   1.085312
# 3               2995  ...   3.434633
# 4              17914  ...   9.102642
# 5               2529  ...   1.613912
# ...              ...  ...        ...
# 236             9862  ...   4.223555
# 237             3539  ...   1.810230
# 238             6643  ...   5.462993
# 239             8132  ...   5.655076
# 240            54348  ...  19.375401
#
# [240 rows x 32 columns]
# time: 65.9 ms (started: 2021-03-27 09:47:10 +00:00)

# %% [markdown]
# ## Group by Socioeconomic

# %%
socio_df.columns

# %%
ignored_columns = ['NBH_NAME', 'EQUIVALENT_BLOCKGROUPS',
                   'Families considered in poverty calculation', 
                   'Individuals considered in poverty calculation', 
                   'Households considered in poverty calculation', 
                   'Families with income below poverty', 
                   'Individuals with income below poverty', 'No schooling completed',
                   'High school diploma',	'Bachelor\'s degree',	'Master\'s degree','Doctorate degree', 'Total population 25 or older',
                   'Total civilian labor force', 'Total employed']
df_normalized =socio_df.copy()
df_normalized['Number of Households'] = df_normalized['Number of Households']/socio_df['Total population']
df_normalized['Total unemployed'] = df_normalized['Total unemployed']/socio_df['Total population']

df_normalized.loc[:, "Total population age 25+ years with a bachelor's degree or higher" : 'Hispanic or Latino'] = df_normalized.loc[:, "Total population age 25+ years with a bachelor's degree or higher" : 'Hispanic or Latino'].div(socio_df['Total population'], axis = 0)
df_normalized.loc[:, "Total Vacant" : 'Total Renter Occupied'] = df_normalized.loc[:, "Total Vacant" : 'Total Renter Occupied'].div(socio_df['Number of Households'], axis = 0)
df_normalized.loc[:, 'Households with income below poverty'] = df_normalized.loc[:, 'Households with income below poverty'].div(socio_df['Households considered in poverty calculation'], axis = 0)
df_normalized = df_normalized.drop(ignored_columns, axis = 1)
df_normalized.head()

# %%
SOCIO_DICT = {
    'Population':    ['Total population'	,'Total Vacant',	 'Total Renter Occupied',	'Number of Households'],
    'Economic':['Median income','Median home value',	 "Total population age 25+ years with a bachelor's degree or higher", 
                'Total unemployed' ,'Households with income below poverty'	 ],
    'Ethnicity': ['White alone','Black or African American alone','Asian alone',	'Hispanic or Latino'],
}
df_population = df_normalized.loc[:, SOCIO_DICT['Population']]
df_economic = df_normalized.loc[:, SOCIO_DICT['Economic']]
df_ethnicity = df_normalized.loc[:, SOCIO_DICT['Ethnicity']]

# %%
df_population.head()

# %% [markdown]
# ## Group by Crime Frequency (Crime/Population)

# %%
import pandas as pd
crime_df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Crime/CrimeData2020-withlocality.csv')
crime_df.head()

# %%
crime_df

# %%
crime_count_df = crime_df.groupby('nbh_name').size().to_frame('crime_records')
crime_count_df = socio_df.merge(crime_count_df, how='inner', left_on='NBH_NAME', right_on='nbh_name')#.drop(columns=['block_id'])
crime_count_df['Crime Records'] = crime_count_df['crime_records']
crime_count_df['Crime Frequency'] = crime_count_df['crime_records']/crime_count_df['Total population']
crime_count_df = crime_count_df.drop('crime_records', axis = 1)
crime_count_df.index = crime_count_df['NBH_NAME']
crime_count_df = crime_count_df[['Crime Records', 'Crime Frequency']]
crime_count_df.sort_values(['Crime Frequency'], axis = 0, ascending=False)

# %% [markdown]
# ##Group by all factors (Cluster of Clusters)

# %%
import ast


merged_df = call_df.loc[:,'Animals':'Water'].round(6)
merged_df['Frequency'] = freq_df['Frequency']

merged_df = pd.concat([merged_df,dept_df.loc[:, 'City Services (dept)':'Water Services (dept)'], response_df.loc[:,response_df.columns[0]:'365+ -day window'], call_df.loc[:,'NBH_ID':'NBH_BOUNDARIES'].copy(), count_df, crime_count_df.loc[:,['Crime Frequency']]], axis = 1).dropna()
merged_df['Boundaries'] = merged_df['NBH_BOUNDARIES'].apply(ast.literal_eval)
merged_df = merged_df.drop('NBH_BOUNDARIES', axis = 1)

master_df = merged_df.copy()
master_df.loc[:, :'365+ -day window'] = master_df.loc[:, :'365+ -day window'].round(5)


master_df_org = pd.concat([call_df_org.round(3),dept_df_org.round(3), response_df_org.round(3), master_df.loc[:,'NBH_ID':'Boundaries'].copy()], axis = 1).dropna()
master_df_org['Boundaries'] = master_df['Boundaries']
master_df_org

# %% [markdown]
# ## Clustering

# %%
'''
Clustering
'''
# !rm -rf exports
# !mkdir 'exports/'
# !mkdir 'exports/KMeans'
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

import numpy as np
from tqdm.notebook import tqdm
import json
import matplotlib.pyplot as plt
distortions_call = []; distortions_dept = []; distortions_response = []; distortions_freq = []; distortions_socioeco = []; distortions_all = []
sil_call = []; sil_dept = []; sil_response = []; sil_freq = []; sil_socioeco = []; sil_all = []
sc = StandardScaler()

for i in tqdm(range(2,10)):
  '''
  Cluster by Call
  '''
  df = merged_df.loc[:,"Animals":"Water"]
  X = np.nan_to_num(df.values)
  cluster_data = sc.fit_transform(X)
  # print(cluster_data[:5])
  kmeans = KMeans(n_clusters=i, random_state=0).fit(cluster_data)
  # kmeans.labels_
  master_df['Cluster by Call Category'] = kmeans.labels_ + 1
  # display(master_df.groupby('Cluster by Call Category').size().to_frame('count'))
  # distortions_call.append(kmeans.inertia_)
  # sil_call.append(silhouette_score(df, kmeans.labels_, metric = 'euclidean'))

  '''
  Cluster by Department
  '''
  df = merged_df.loc[:, 'City Services (dept)':'Water Services (dept)']
  X = np.nan_to_num(df.values)
  cluster_data = sc.fit_transform(X)
  # print(cluster_data[:5])
  kmeans = KMeans(n_clusters=i, random_state=0).fit(cluster_data)
  # kmeans.labels_
  master_df['Cluster by Department'] = kmeans.labels_ + 1
  # display(master_df.groupby('Cluster by Category').size().to_frame('count'))
  distortions_dept.append(kmeans.inertia_)
  sil_dept.append(silhouette_score(df, kmeans.labels_, metric = 'euclidean'))

  '''
  Response Time (Days to Close) Clustering
  '''
  df = merged_df.iloc[:,:-5]
  X = np.nan_to_num(df.values)
  cluster_data = sc.fit_transform(X)
  # print(cluster_data[:5])
  kmeans = KMeans(n_clusters=i, random_state=0).fit(cluster_data)
  master_df['Cluster by Response Time'] = kmeans.labels_ + 1
  # display(master_df.groupby('Cluster by Response Time').size().to_frame('count'))
  distortions_response.append(kmeans.inertia_)
  sil_response.append(silhouette_score(df, kmeans.labels_, metric = 'euclidean'))
  
  '''
  Call Frequency Clustering
  '''
  df = merged_df['Frequency'].to_frame('Frequency')
  X = np.nan_to_num(df.values)
  cluster_data = sc.fit_transform(X)
  # print(cluster_data[:5])
  kmeans = KMeans(n_clusters=i, random_state=0).fit(cluster_data)
  master_df['Cluster by Call Frequency'] = kmeans.labels_ + 1
  # display(master_df.groupby('Cluster by Call Frequency').size().to_frame('count'))
  distortions_freq.append(kmeans.inertia_)
  sil_freq.append(silhouette_score(df , kmeans.labels_, metric = 'euclidean'))
  

  '''
  Socio Economic Clustering
  '''
  
  '''
    Population Attribute Group
  '''
  df = df_population.copy()
  X = np.nan_to_num(df.values)
  cluster_data = sc.fit_transform(X)
  # print(len(cluster_data))
  kmeans = KMeans(n_clusters=i, random_state=0).fit(cluster_data)
  # print(len(kmeans.labels_))
  master_df['Cluster by Population Attr Group'] = kmeans.labels_ + 1
  '''
    Economic Attribute Group
  '''
  df = df_economic.copy()
  X = np.nan_to_num(df.values)
  cluster_data = sc.fit_transform(X)
  # print(cluster_data[:5])
  kmeans = KMeans(n_clusters=i, random_state=0).fit(cluster_data)
  master_df['Cluster by Economic Attr Group'] = kmeans.labels_ + 1
  '''
    Ethnicity Attribute Group
  '''
  df = df_ethnicity.copy()
  X = np.nan_to_num(df.values)
  cluster_data = sc.fit_transform(X)
  # print(cluster_data[:5])
  kmeans = KMeans(n_clusters=i, random_state=0).fit(cluster_data)
  master_df['Cluster by Ethnicity Attr Group'] = kmeans.labels_ + 1



  df = master_df[['Cluster by Population Attr Group', 'Cluster by Economic Attr Group', 'Cluster by Ethnicity Attr Group']].astype(int)
  kmeans = KMeans(n_clusters=i, random_state=0).fit(df)
  kmeans.labels_
  master_df['Cluster by Socioeconomic Metrics'] = kmeans.labels_ + 1
  # display(master_df.groupby('Cluster by Socioeconomic Metrics').size().to_frame('count'))

  distortions_socioeco.append(kmeans.inertia_)
  sil_socioeco.append(silhouette_score(df, kmeans.labels_, metric = 'euclidean'))

  '''
  Clustering by Crime
  '''
  df = merged_df['Crime Frequency'].to_frame('Frequency')
  X = np.nan_to_num(df.values)
  cluster_data = sc.fit_transform(X)
  # print(cluster_data[:5])
  kmeans = KMeans(n_clusters=i, random_state=0).fit(cluster_data)
  master_df['Cluster by Crime Frequency'] = kmeans.labels_ + 1
  # display(master_df.groupby('Cluster by Call Frequency').size().to_frame('count'))
  distortions_freq.append(kmeans.inertia_)
  sil_freq.append(silhouette_score(df , kmeans.labels_, metric = 'euclidean'))
  

  '''
  All-factor Clustering
  '''
  df = master_df[['Cluster by Call Category', 'Cluster by Department', 'Cluster by Response Time', 'Cluster by Call Frequency', 'Cluster by Socioeconomic Metrics', 'Cluster by Crime Frequency']]
  kmeans = KMeans(n_clusters=i, random_state=0).fit(df)
  master_df['Cluster by All Factors'] = kmeans.labels_ + 1
  # display(master_df.groupby('Cluster by All Factors').size().to_frame('count')).
  distortions_all.append(kmeans.inertia_)
  sil_all.append(silhouette_score(df, kmeans.labels_, metric = 'euclidean'))
  master_df = master_df.sort_values('Cluster by Call Category')

  master_df.to_csv('exports/KMeans/246NBH-{}clusters-KMeans.csv'.format(str(i)), index = False)
  with open('exports/KMeans/246NBH-{}clusters-KMeans.json'.format(i), 'w') as f:
    bg_dict = master_df.to_dict('index')
    bg_dict['Cluster_Total'] = i
    f.write(json.dumps(bg_dict))

  
  # break

# %%
input()

# %%
master_df

# %%
master_df.head()

# %%
Optimal_K = {
    'Cluster by Call Category': 3,
    'Cluster by Response Time': 4,
    'Cluster by Call Frequency': 3,
    'Cluster by Socioeconomic Metrics': 3,
}
# sil = sil_call; distortions = distortions_call
# sil = sil_response; distortions = distortions_response
# sil = sil_freq; distortions = distortions_freq
# sil = sil_socioeco; distortions = distortions_socioeco
sil = sil_all; distortions = distortions_all



plt.plot(range(2, 10), sil, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Scores')
plt.show()

plt.plot(range(2, 10), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortions')
plt.show()

# %%
call_df.to_csv('exports/246NBH-groupby-CATEGORY.csv', index = False)
response_df.to_csv('exports/246NBH-groupby-RESPONSE_TIME.csv', index = False)
freq_df.to_csv('exports/246NBH-groupby-CALL_FREQUENCY.csv', index = False)
crime_count_df.to_csv('exports/246NBH-groupby-CRIME_FREQUENCY.csv', index = False)

merged_df.to_csv('exports/246NBH-all_info.csv', index = False)

# %%
# !mkdir "/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/exports"
# !zip -r NBH246_clusters.zip exports
# !cp NBH246_clusters.zip "/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/"

# %% [markdown]
# # Cluster Profiling

# %%
# !mkdir data/
# !cp "/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/246/NBH246_clusters.zip" ./
# !unzip NBH246_clusters.zip

# %%
import pandas as pd

allinfo_df = pd.read_csv('/content/exports/246NBH-all_info.csv')
allinfo_df.index = allinfo_df['NBH_ID']
allinfo_df.head()

# %%
import pandas as pd
import json
from tqdm.notebook import tqdm
cluster_columns = ['Cluster by Call Category', 'Cluster by Department', 
                   'Cluster by Response Time', 'Cluster by Call Frequency', 
                   'Cluster by Socioeconomic Metrics', 'Cluster by Crime Frequency', 'Cluster by All Factors']
for i in tqdm(range(2,10)):
  df = pd.read_csv('exports/KMeans/246NBH-{}clusters-KMeans.csv'.format(str(i)))

  max_num = df['Cluster by Call Category'].max()
  print(max_num)
  # display(df.describe())
  with open('exports/KMeans/246NBH-{}clusters-KMeans.json'.format(i), 'r') as f:
        clusters_ann = json.load(f)
        clusters_ann['Cluster_Profiles'] = {}
  for col in cluster_columns:
    print(col)
    columns = allinfo_df.columns
    cluster_profiles = []
    for i in range(1,max_num+1):
      # print(i)
      cluster_members = df[df[col] == i]['NBH_ID'].values.tolist()

      if 'Call Category' in col:
        sub_df = allinfo_df.copy().loc[:, 'Animals': 'Water']
      elif 'Department' in col:
        sub_df = allinfo_df.copy().loc[:, 'City Services (dept)': 'Water Services (dept)']
      elif 'Response Time' in col:
        sub_df = allinfo_df.copy().loc[:, 'On time (0-day delay)': '365+ -day window']
      elif 'Call Frequency' in col:
        sub_df = allinfo_df.copy().loc[:, 'Frequency'].to_frame('Frequency')
      elif 'Socioeconomic' in col:
        sub_df = allinfo_df.copy().loc[:, 'Total population': 'Doctorate degree']
      elif 'Crime' in col:
        sub_df = allinfo_df.copy().loc[:, 'Crime Frequency'].to_frame('Crime Frequency')
      else:
        sub_df = allinfo_df.copy().loc[:, 'Animals': 'Crime Frequency'].drop(['NBH_ID', 'NBH_NAME', 'EQUIVALENT_BLOCKGROUPS'], axis = 1)

      single_df = sub_df[sub_df.index.isin(cluster_members)]
      # display(single_df.head())
      if len(single_df) > 1:
        profile_df = single_df.describe(include='all').round(5)#.astype(int)
      else:
        profile_df = single_df.describe(include='all').fillna('N/A')

      if 'Call Category' in col or 'Department' in col:
        profile_df = profile_df.sort_values(by = 'mean', axis = 1, ascending = False)
      # display(profile_df)
      
      profile_dict = profile_df.to_dict()
      profile_dict['Cluster_ID'] = i
      cluster_profiles.append(profile_dict)
    clusters_ann['Cluster_Profiles'][col] = cluster_profiles
  with open('exports/KMeans/246NBH-{}clusters-KMeans.json'.format(i), 'w') as f:
        f.write(json.dumps(clusters_ann))
    # break
  # break

# %%
clusters_ann['15']

# %%
for k,v in clusters_ann['Cluster_Profiles']['Cluster by All Factors'][0].items():
  print('original:',k, v)
  print(json.dumps(v))

# %%
with open('exports/KMeans/246NBH-{}clusters-KMeans.json'.format('6'), 'r') as f:
        clusters_ann = json.load(f)
len(clusters_ann['Cluster_Profiles']['Cluster by Response Time'])
clusters_ann['Cluster_Profiles']['Cluster by Crime Frequency']
# clusters_ann['290370601001']

# %%
single_df.describe().fillna('N/A')

# %%
input()

# %%
metadata = {}
cols = allinfo_df.copy().loc[:, 'Animals': 'Water'].columns.tolist()
metadata['Categories'] = cols
cols = allinfo_df.copy().loc[:, 'City Services (dept)': 'Water Services (dept)'].columns.tolist()
metadata['Departments'] = cols
cols = allinfo_df.copy().loc[:, 'On time (0-day delay)': '365+ -day window'].columns.tolist()
metadata['Response Times'] = cols
cols = allinfo_df.copy().loc[:, 'Frequency'].to_frame('Frequency').columns.tolist()
metadata['Frequency'] = cols
cols = allinfo_df.copy().loc[:, 'Total population': 'Doctorate degree'].columns.tolist()
metadata['Socioeconomic Metrics'] = cols
cols = allinfo_df.copy().loc[:, 'Crime Frequency'].to_frame('Crime Frequency').columns.tolist()
metadata['Crime Frequency'] = cols
metadata

from glob import glob
import json
NBH_cluster_info = [metadata]
NBH_list = glob('./exports/KMeans/*.json')
for path in NBH_list:
  with open(path) as f:
    temp = json.load(f)
    keys = list(temp.keys())[:] + ['Cluster_Total']
    filtered_dict = {k: temp[k] for k in keys}
    NBH_cluster_info.append(filtered_dict)
  # break
# NBH_cluster_info = json.dumps(NBH_cluster_info)

# %%
metadata['Categories']

# %%
for k,v in NBH_cluster_info[1].items():
  print(k,v)
  for j,l in metadata.items():
    for col in l:
      if col not in v:
        print('not exists')
  # break

# %%
NBH_cluster_info[1]['15']['crime_frequency']

# %%
NBH_cluster_info[0]

# %%
NBH_cluster_info[1]['Cluster_Profiles']['Cluster by Socioeconomic Metrics']

# %%
with open('exports/246NBH-Clusters.json', 'w') as f:
  f.write(json.dumps(NBH_cluster_info))

# %%
BG_cluster_info[0]

# %%
# !mkdir "/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/246"
# !zip -r NBH246_clusters.zip exports
# !cp NBH246_clusters.zip "/content/gdrive/MyDrive/Colab Notebooks/NSF-SCC Project/Neighborhood Data/Census/246"

# %%
df_311['CLOSED YEAR'].unique()

# %%
input()
